# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
###################################
# TensorFlow wizardry
import tensorflow as tf
config = tf.ConfigProto()
 
# Don’t pre-allocate memory; allocate as-needed
config.gpu_options.allow_growth = True
 
# Only allow a total of half the GPU memory to be allocated
config.gpu_options.per_process_gpu_memory_fraction = 0.05
#gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.333)
 
# Create a session with the above options specified.
from keras import optimizers, regularizers
from keras.layers.normalization import BatchNormalization
from keras.utils import to_categorical
from keras.wrappers.scikit_learn import KerasClassifier
from keras import optimizers
from keras.constraints import maxnorm
from keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping

from keras.models import Sequential, Model, load_model
from keras.layers import Activation, Dense, Dropout, Input
from keras import backend as k

k.tensorflow_backend.set_session(tf.Session(config=config))
#k.tensorflow_backend.set_session(tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
###################################

# %%
#----------------------------------Import modules------------------------------
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score, roc_curve, auc
from sklearn import preprocessing
sns.set_style("whitegrid")
np.random.seed(23)
import time
from sklearn.model_selection import GridSearchCV
import sklearn.metrics as sm
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_predict


neurons=66
batch_size=66
dsnum=20

# %%
if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device: /device:GPU:0

# %%
pathds = '/home/user/01Code/00Datasets_final/'

# %%
#df_chunk = pd.read_csv(pathds+'SubsetAllSamples/ThirdCloneID10bal_minmax.csv', chunksize=1000)
#df = df_chunk.get_chunk(300000)
df = pd.read_csv(pathds+"SubsetAllSamples/ThirdCloneID"+str(dsnum)+"bal_stdscal.csv")

# %%
df.shape
# Out:
# (504576, 67)

# %% [markdown]
# #### 4.2 Explaining the data

# %%
#if you don't have an intuitive sense of how imbalanced these two classes are, let's go visual
count_classes = pd.value_counts(df['class'], sort = True)
print('Class 0:', count_classes[0])
print('Class 1:', count_classes[1])
print('Proportion:', round(count_classes[0] / count_classes[1], 3), ': 1')
# Out:
# Class 0: 252288
# Class 1: 252288
# Proportion: 1.0 : 1

# %%
count_classes.plot(kind = 'bar', rot=0)
plt.xticks(range(2), ['Normal [0]','Malicious [1]'])
plt.title("Frequency by observation number")
plt.xlabel("Class")
plt.ylabel("Number of Observations");

# %%
#set random seed and percentage of test data
RANDOM_SEED = 23 #used to help randomly select the data points
TEST_PCT = 0.20 # 20% of the data

# %%
train, test_df = train_test_split(df, test_size=TEST_PCT, random_state=RANDOM_SEED)

# %% [markdown]
# + df -> original dataset
# + train -> subset of 80% from original dataset
# + test_df -> subset of 20% from original dataset

# %%
train_df, dev_df = train_test_split(train, test_size=TEST_PCT, random_state=RANDOM_SEED)

# %% [markdown]
# + train -> subset of 80% from original dataset
# + train_df -> subset of 80% from train
# + dev_df -> subset of 20% from train

# %%
# Check distribution of mal samples in train and test set
print(train_df.iloc[:, batch_size].sum()/train_df.shape[0]) 
print(dev_df.iloc[:, batch_size].sum()/dev_df.shape[0]) 
print(test_df.iloc[:, batch_size].sum()/test_df.shape[0])
# Out:
# 0.5015514294207997
# 0.4981915473418223
# 0.4964822228387966

# %%
train_x = train_df.iloc[:, :batch_size] 
dev_x = dev_df.iloc[:, :batch_size] 
test_x = test_df.iloc[:, :batch_size]

# %% [markdown]
# + train_x -> features of train_df **Training subset for AE**
# + dev_x -> features of dev_df **Validation subset for AE**
# + test_x -> features of test_df **Testing subset for ANN**

# %%
# Define the final train and test sets
train_y = train_df.iloc[:,batch_size]
dev_y = dev_df.iloc[:,batch_size]
test_y = test_df.iloc[:,batch_size]

# %% [markdown]
# + train_y -> **Labels for supervised training of ANN**
# + dev_y -> labels of dev_df  *not used for AE neither ANN*
# + test_y -> labels of test_df  **Ground Truth for predictions of supervised ANN**

# %%
train_x =np.array(train_x)
dev_x =np.array(dev_x)
test_x = np.array(test_x)

train_y = np.array(train_y)
dev_y = np.array(dev_y)
test_y = np.array(test_y)

print(train_x.shape[1])
# Out:
# 66

# %% [markdown]
# ### Autoencoder Function

# %%
def ae(factor_enc_dim, enc_activation, dec_activation, 
                optimizer, loss):

    encoding_dim = int(int(train_x.shape[1])/factor_enc_dim)
    ### Define input layer
    input_data = Input(shape=(train_x.shape[1],))
    ### Define encoding layer #RELU
    encoded = Dense(encoding_dim, activation=enc_activation, name='encoded_bottle_neck')(input_data)
    ### Define decoding layer #SIMOID
    decoded = Dense(train_x.shape[1], activation=dec_activation)(encoded)
    ### Create the autoencoder model
    autoencoder = Model(input_data, decoded)
    autoencoder.compile(optimizer=optimizer,
                        loss=loss,
                        metrics=['accuracy'])
    
    print(autoencoder.summary())
    
    encoder = Model(input_data, encoded)
    encoded_train_x = encoder.predict(train_x)
    encoded_test_x = encoder.predict(test_x)
    
    return autoencoder,encoded_train_x,encoded_test_x

# %%
def sae(factor_enc_dim, enc_activation, dec_activation,
        optimizer, loss):

    encoding_dim = int(int(train_x.shape[1])/factor_enc_dim)
    ### Define input layer
    input_data = Input(shape=(train_x.shape[1],))
    ### Define encoding layer
    encoded = Dense(encoding_dim, activation=enc_activation, name='input_layer')(input_data)
    encoded = Dense(int(encoding_dim/2), activation=enc_activation)(encoded) ##Stacked AE
    encoded_bottle_neck = Dense(int(encoding_dim/4), activation=enc_activation, name='enc_bottle_neck')(encoded) ##Stacked AE
    
    ### Define decoding layer
    decoded = Dense(int(encoding_dim/2), activation=enc_activation)(encoded_bottle_neck) ##Stacked AE
    decoded = Dense(encoding_dim, activation=enc_activation)(decoded) ##Stacked AE
    decoded = Dense(train_x.shape[1], activation=dec_activation)(decoded)
    
    ### Create the autoencoder model
    sae = Model(input_data, decoded)
    sae.compile(optimizer=optimizer,
                loss=loss,
                metrics=['accuracy'])
    
    print(sae.summary())

    encoder = Model(input_data, encoded_bottle_neck)
    encoded_train_x = encoder.predict(train_x)
    encoded_test_x = encoder.predict(test_x)
    
    return sae,encoded_train_x,encoded_test_x

# %%
def spae(factor_enc_dim,dec_activation,enc_activation,
         optimizer,loss):

    encoding_dim = int(int(train_x.shape[1])/factor_enc_dim)
    ### Define input layer
    input_data = Input(shape=(train_x.shape[1],))
    ### Define encoding layer
    encoded = Dense(encoding_dim, activity_regularizer=regularizers.l1(1e-4), activation=enc_activation, name='encoded_bottle_neck')(input_data)
    ### Define decoding layer
    decoded = Dense(train_x.shape[1], activation=dec_activation)(encoded)
    ### Create the autoencoder model
    autoencoder = Model(input_data, decoded)
    autoencoder.compile(optimizer=optimizer,
                        loss=loss,
                        metrics=['accuracy'])
    
    print(autoencoder.summary())
    
    encoder = Model(input_data, encoded)
    encoded_train_x = encoder.predict(train_x)
    encoded_test_x = encoder.predict(test_x)
    
    return autoencoder,encoded_train_x,encoded_test_x

# %%
def fit_ae(checkpoint_file, autoencoder,
           epochs, batch_size, shuffle):
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5)

    cp = ModelCheckpoint(filepath=checkpoint_file,
                                   save_best_only=True,
                                   verbose=0)

    tb = TensorBoard(log_dir='./logs',
                    histogram_freq=0,
                    write_graph=True,
                    write_images=True)

    start_time = time.time()
    print(time.ctime(start_time))

    hist_auto = autoencoder.fit(train_x, train_x,
                    epochs=epochs,
                    batch_size=batch_size,
                    shuffle=shuffle,
                    verbose=1,
                    callbacks=[early_stopping, cp, tb],
                    validation_data=(dev_x, dev_x))

    elapsed_time = (time.time() - start_time)
    print("--- AE spent %s seconds ---" % elapsed_time)
    
    return hist_auto

# %%
def plot_hist_auto(hist_auto, fig_file):
    best_loss_value = hist_auto.history['loss'][-1]
    print('Best loss value:', best_loss_value)

    # Summarize history for loss
    plt.figure()
    plt.plot(hist_auto.history['loss'])
    plt.plot(hist_auto.history['val_loss'])
    plt.title('Autoencoder model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.savefig(fig_file)
    plt.show()
    
    return best_loss_value

# %%
def ann_2h(neurons,encoded_train_x,init_mode,activation_input,
               weight_constraint,dropout_rate,activation_output,
               loss,optimizer):

    # create model
    model = Sequential()

    model.add(Dense(neurons, input_dim=encoded_train_x.shape[1],
                    kernel_initializer=init_mode,
                    #kernel_regularizer=regularizers.l2(0.02), #from example
                    activation=activation_input,
                    kernel_constraint=maxnorm(weight_constraint)
                    )
              )

#     #Hidden Layer
    model.add(Dense(int(neurons-int(neurons/4)), activation="relu", kernel_initializer=init_mode)) #rezvy

    model.add(Dense(int(neurons-int((neurons/4)*2)), activation="relu", kernel_initializer=init_mode)) #rezvy
    model.add(BatchNormalization()) #commented for ex
    model.add(Dropout(dropout_rate))
    
    model.add(Dense(1, activation=activation_output)) #example
    
    # Compile model
    model.compile(loss=loss, 
                  optimizer=optimizer, 
                  metrics=['accuracy'])
    
    print(model.summary())
    
    return model

# %%
def ann_2h_(neurons,encoded_train_x,init_mode,activation_input,
               dropout_rate,activation_output,
               loss,lr):

    # create model
    model = Sequential()

    model.add(Dense(neurons, input_dim=encoded_train_x.shape[1],
                    kernel_initializer=init_mode,
                    #kernel_regularizer=regularizers.l2(0.02), #from example
                    activation=activation_input,
#                     kernel_constraint=maxnorm(weight_constraint)
#                     kernel_constraint=maxnorm(weight_constraint)
                    )
              )

#     #Hidden Layer
    model.add(Dense(int(neurons-int(neurons/4)), activation="relu")) #rezvy

    model.add(Dense(int(neurons-int((neurons/4)*2)), activation="relu")) #rezvy
    model.add(BatchNormalization()) #commented for ex
    model.add(Dropout(dropout_rate))
    
    model.add(Dense(1, activation=activation_output)) #example

    optimizer = optimizers.Adam(lr=lr)
    
    # Compile model
    model.compile(loss=loss, 
                  optimizer=optimizer, 
                  metrics=['accuracy'])
    
    print(model.summary())
    
    return model

# %%
def ann_2h__(neurons,encoded_train_x,activation_input,
             activation_output,loss,optimizer):

    # create model
    model = Sequential()

    model.add(Dense(neurons, input_dim=encoded_train_x.shape[1],
#                     kernel_initializer=init_mode,
                    #kernel_regularizer=regularizers.l2(0.02), #from example
                    activation=activation_input,
#                     kernel_constraint=maxnorm(weight_constraint)
#                     kernel_constraint=maxnorm(weight_constraint)
                    )
              )

#     #Hidden Layer
    model.add(Dense(int(neurons-int(neurons/4)), activation="relu")) #rezvy

    model.add(Dense(int(neurons-int((neurons/4)*2)), activation="relu")) #rezvy
#     model.add(BatchNormalization()) #commented for ex
#     model.add(Dropout(dropout_rate))
    
    model.add(Dense(1, activation=activation_output)) #example

#     optimizer = optimizers.Adam(lr=lr)
    
    # Compile model
    model.compile(loss=loss, 
                  optimizer=optimizer, 
                  metrics=['accuracy'])
    
    print(model.summary())
    
    return model

# %%
def ann_1h_36n(neurons,encoded_train_x,init_mode,activation_input,
               weight_constraint,dropout_rate,activation_output,
               loss,optimizer):

    # create model
    model = Sequential()

    model.add(Dense(neurons, input_dim=encoded_train_x.shape[1],
                    kernel_initializer=init_mode,
                    #kernel_regularizer=regularizers.l2(0.02), #from example
                    activation=activation_input,
                    kernel_constraint=maxnorm(weight_constraint)
                    )
              )

#     #Hidden Layer
    model.add(Dense(int(neurons-int(neurons/4)), activation="relu", kernel_initializer=init_mode)) #rezvy
    model.add(BatchNormalization()) #commented for ex
    model.add(Dropout(dropout_rate))
    
    model.add(Dense(1, activation=activation_output)) #example
    
    # Compile model
    model.compile(loss=loss, 
                  optimizer=optimizer, 
                  metrics=['accuracy'])
    
    print(model.summary())
    
    return model

# %%
def ann_1h_24n(neurons,encoded_train_x,init_mode,activation_input,
               weight_constraint,dropout_rate,activation_output,
               loss,optimizer):

    # create model
    model = Sequential()

    model.add(Dense(neurons, input_dim=encoded_train_x.shape[1],
                    kernel_initializer=init_mode,
                    #kernel_regularizer=regularizers.l2(0.02), #from example
                    activation=activation_input,
                    kernel_constraint=maxnorm(weight_constraint)
                    )
              )

#     #Hidden Layer
    model.add(Dense(int(neurons-int(neurons/4)), activation="relu", kernel_initializer=init_mode)) #rezvy
    model.add(BatchNormalization()) #commented for ex
    model.add(Dropout(dropout_rate))
    
    model.add(Dense(1, activation=activation_output)) #example
    
    # Compile model
    model.compile(loss=loss, 
                  optimizer=optimizer, 
                  metrics=['accuracy'])
    
    print(model.summary())
    
    return model

# %%
def ann_1h_24n_(neurons,encoded_train_x,activation_input,
               activation_output,loss,optimizer):

    # create model
    model = Sequential()

    model.add(Dense(neurons, input_dim=encoded_train_x.shape[1],
#                     kernel_initializer=init_mode,
                    #kernel_regularizer=regularizers.l2(0.02), #from example
                    activation=activation_input,
#                     kernel_constraint=maxnorm(weight_constraint)
                    )
              )

#     #Hidden Layer
    model.add(Dense(int(neurons-int(neurons/4)), activation="relu")) #rezvy
    
#     model.add(BatchNormalization()) #commented for ex
#     model.add(Dropout(dropout_rate))
    
    model.add(Dense(1, activation=activation_output)) #example
    
    # Compile model
    model.compile(loss=loss, 
                  optimizer=optimizer, 
                  metrics=['accuracy'])
    
    print(model.summary())
    
    return model

# %%
def ann_fit(checkpoint_file,ann,enc_train_x,train_y,epochs,shuffle,batch_size):
    early_stopping = EarlyStopping(monitor='val_loss', patience=5)

    cp = ModelCheckpoint(filepath=checkpoint_file,
                                   save_best_only=True,
                                   verbose=0)

    tb = TensorBoard(log_dir='./logs',
                    histogram_freq=0,
                    write_graph=True,
                    write_images=True)

    start_time = time.time()
    print(time.ctime(start_time))

    history = ann.fit(enc_train_x,
                      train_y,
                      validation_split=0.2,
                      callbacks=[early_stopping],
                      epochs=epochs,
                      shuffle=shuffle,
                      batch_size=batch_size,
                      verbose=1)

    elapsed_time = (time.time() - start_time)
    print("--- ANN spent %s seconds ---" % elapsed_time)

    return history

# %%
def ann_predict(ann,enc_test_x):
    pred_ann_prob = ann.predict(enc_test_x)
    pred_ann_prob.shape
    pred_ann_prob = pred_ann_prob[:,0]
    pred_ann_01 = np.where(pred_ann_prob > 0.5, 1, 0)
    
    #Print accuracy
    acc_ann = accuracy_score(test_y, pred_ann_01)
    print('Overall accuracy of Neural Network model:', acc_ann)

    classiBM = "NN"
    preBM = (sm.precision_score(test_y, pred_ann_01)*100) 
    recallBM = (sm.recall_score(test_y, pred_ann_01)*100) 
    f1scoreBM = (sm.f1_score(test_y, pred_ann_01)*100)
    print(sm.classification_report(test_y, pred_ann_01,digits=4))
    
    return pred_ann_prob, pred_ann_01

# %%
def ann_predict_(ann,enc_test_x,epochs,batch_size):
    #pred_ann_prob = ann.predict(enc_test_x)
    
    start_time = time.time()
    print(time.ctime(start_time))    
    
    model = KerasClassifier(build_fn=ann, epochs=epochs, batch_size=batch_size, verbose=1)
#     kfold = StratifiedKFold(n_splits=10, random_state=seed)
    
    pred_ann_prob = cross_val_predict(estimator=model,
                              X=np.array(enc_test_x),
                              y=test_y,
                              cv=KFold(n_splits=5, random_state=23, shuffle=True))

    elapsed_time = (time.time() - start_time)
    print("--- %s seconds ---" %elapsed_time)
    
    pred_ann_prob.shape
    pred_ann_prob = pred_ann_prob[:,0]
    pred_ann_01 = np.where(pred_ann_prob > 0.5, 1, 0)
    
    #Print accuracy
    acc_ann = accuracy_score(test_y, pred_ann_01)
    print('Overall accuracy of Neural Network model:', acc_ann)

    classiBM = "NN"
    preBM = (sm.precision_score(test_y, pred_ann_01)*100) 
    recallBM = (sm.recall_score(test_y, pred_ann_01)*100) 
    f1scoreBM = (sm.f1_score(test_y, pred_ann_01)*100)
    print(sm.classification_report(test_y, pred_ann_01,digits=4))
    
    return pred_ann_prob, pred_ann_01

# %%
def plot_roc_cm(pred_ann_prob, pred_ann_01, roc_file, cm_file):
    false_positive_rate, recall, thresholds = roc_curve(test_y, pred_ann_prob)
    roc_auc = auc(false_positive_rate, recall)
    plt.figure()
    plt.title('Receiver Operating Characteristic (ROC)')
    plt.plot(false_positive_rate, recall, 'b', label = 'AUC = %0.3f' %roc_auc)
    plt.legend(loc='lower right')
    plt.plot([0,1], [0,1], 'r--')
    plt.xlim([0.0,1.0])
    plt.ylim([0.0,1.0])
    plt.ylabel('Recall')
    plt.xlabel('Fall-out (1-Specificity)')
    plt.savefig(roc_file)
    plt.show()
    
    cm = confusion_matrix(test_y, pred_ann_01)
    labels = ['Normal', 'Malicious']
    plt.figure(figsize=(8,6))
    sns.heatmap(cm,xticklabels=labels, yticklabels=labels, annot=True, fmt='d', cmap="RdYlGn", vmin = 0.2);
    plt.title('Confusion Matrix')
    plt.ylabel('True Class')
    plt.xlabel('Predicted Class')
    plt.savefig(cm_file)
    plt.show()

# %%
ae_sigmoid_adam_logcosh,enc_train_x_asal,enc_test_x_asal = ae(factor_enc_dim = 1.5,
                                                              enc_activation = 'relu',
                                                              dec_activation = 'sigmoid',
                                                              optimizer='Adam',
                                                              loss='logcosh')
# Out:
# WARNING:tensorflow:From /home/user/anaconda3/envs/deepl/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 66)                0
# _________________________________________________________________
# encoded_bottle_neck (Dense)  (None, 44)                2948
# _________________________________________________________________
# dense_1 (Dense)              (None, 66)                2970
# =================================================================
# Total params: 5,918
# Trainable params: 5,918
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#ae_sigmoid_adam_logcosh = load_model('ae_sigmoid_adam_logcosh_redds10bal.h5')

# %%
hist_ae_sigmoid_adam_logcosh = fit_ae(checkpoint_file = "ae_sigmoid_adam_logcosh_redds"+str(dsnum)+"bal.h5",
                                        autoencoder = ae_sigmoid_adam_logcosh, 
                                        epochs = 200, 
                                        batch_size = batch_size, 
                                        shuffle = False)
# Out:
# Wed Jun 12 13:14:45 2019
# WARNING:tensorflow:From /home/user/anaconda3/envs/deepl/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 322928 samples, validate on 80732 samples
# Epoch 1/200
# 322928/322928 [==============================] - 9s 28us/step - loss: 0.0572 - acc: 0.1879 - val_loss: 0.0522 - val_acc: 0.2061
# Epoch 2/200
# 322928/322928 [==============================] - 9s 28us/step - loss: 0.0522 - acc: 0.2097 - val_loss: 0.0521 - val_acc: 0.2068
# Epoch 3/200
# 322928/322928 [==============================] - 9s 27us/step - loss: 0.0522 - acc: 0.2005 - val_loss: 0.0521 - val_acc: 0.1925
# Epoch 4/200
# 322928/322928 [==============================] - 9s 27us/step - loss: 0.0522 - acc: 0.1863 - val_loss: 0.0521 - val_acc: 0.1789
# Epoch 5/200
# 322928/322928 [==============================] - 9s 27us/step - loss: 0.0522 - acc: 0.1752 - val_loss: 0.0521 - val_acc: 0.1708
# Epoch 6/200
# 322928/322928 [==============================] - 9s 27us/step - loss: 0.0522 - acc: 0.1722 - val_loss: 0.0521 - val_acc: 0.1687
200
# 322928/322928 [==============================] - 10s 31us/step - loss: 0.0521 - acc: 0.2199 - val_loss: 0.0520 - val_acc: 0.2184
# Epoch 149/200
# 322928/322928 [==============================] - 10s 32us/step - loss: 0.0521 - acc: 0.2198 - val_loss: 0.0520 - val_acc: 0.2194
# Epoch 150/200
# 322928/322928 [==============================] - 10s 31us/step - loss: 0.0521 - acc: 0.2193 - val_loss: 0.0520 - val_acc: 0.2181
# Epoch 151/200
# 322928/322928 [==============================] - 10s 31us/step - loss: 0.0521 - acc: 0.2210 - val_loss: 0.0520 - val_acc: 0.2216
# --- AE spent 1244.2844257354736 seconds ---

# %%
best_loss_value_ae_sigmoid_adam_logcosh = plot_hist_auto(hist_ae_sigmoid_adam_logcosh, './Figures/ae_sigmoid_adam_logcosh'+str(dsnum)+'.png')
# Out:
# Best loss value: 0.052111386396745764

# %%
ae_siglin_adam_logcosh,enc_train_x_aslal,enc_test_x_aslal = ae(factor_enc_dim = 1.5,
                                                              enc_activation = 'sigmoid',
                                                              dec_activation = 'linear',
                                                              optimizer='Adam',
                                                              loss='logcosh')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 66)                0
# _________________________________________________________________
# encoded_bottle_neck (Dense)  (None, 44)                2948
# _________________________________________________________________
# dense_2 (Dense)              (None, 66)                2970
# =================================================================
# Total params: 5,918
# Trainable params: 5,918
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#ae_siglin_adam_logcosh = load_model('ae_siglin_adam_logcosh_redds10bal.h5')

# %%
hist_ae_siglin_adam_logcosh = fit_ae(checkpoint_file = "ae_siglin_adam_logcosh_redds"+str(dsnum)+"bal.h5",
                                        autoencoder = ae_siglin_adam_logcosh, 
                                        epochs = 200, 
                                        batch_size = batch_size, 
                                        shuffle = False)
# Out:
# Wed Jun 12 13:35:35 2019
# Train on 322928 samples, validate on 80732 samples
# Epoch 1/200
# 322928/322928 [==============================] - 10s 31us/step - loss: 0.0086 - acc: 0.6506 - val_loss: 0.0011 - val_acc: 0.7401
# Epoch 2/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 9.7563e-04 - acc: 0.7616 - val_loss: 8.2061e-04 - val_acc: 0.7911
# Epoch 3/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 8.5421e-04 - acc: 0.7692 - val_loss: 7.6250e-04 - val_acc: 0.7918
# Epoch 4/200
# 322928/322928 [==============================] - 9s 29us/step - loss: 8.1478e-04 - acc: 0.7764 - val_loss: 7.3550e-04 - val_acc: 0.7994
# Epoch 5/200
# 322928/322928 [==============================] - 9s 29us/step - loss: 7.9188e-04 - acc: 0.7836 - val_loss: 7.1911e-04 - val_acc: 0.8201
# Epoch 6/200
# 322928/322928 [==============================] - 9s 29us/step - loss: 7.7699e-04 - acc: 0.7884 - val_loss: 7.0959e-04 - val_acc: 0.8062
# Epoch 7/200
# 322928/322928 [==============================] - 9s 29us/step - loss: 7.6820e-04 - acc: 0.7896 - val_loss: 7.0402e-04 - val_acc: 0.7842
# Epoch 8/200
# 322928/322928 [==============================] - 10s 30us/step - loss:
200
# 322928/322928 [==============================] - 10s 30us/step - loss: 7.4211e-04 - acc: 0.7841 - val_loss: 6.8135e-04 - val_acc: 0.7502
# Epoch 100/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 7.4210e-04 - acc: 0.7857 - val_loss: 6.8100e-04 - val_acc: 0.8007
# Epoch 101/200
# 322928/322928 [==============================] - 10s 31us/step - loss: 7.4196e-04 - acc: 0.7847 - val_loss: 6.8105e-04 - val_acc: 0.6976
# Epoch 102/200
# 322928/322928 [==============================] - 10s 31us/step - loss: 7.4196e-04 - acc: 0.7845 - val_loss: 6.8104e-04 - val_acc: 0.7025
# Epoch 103/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 7.4195e-04 - acc: 0.7860 - val_loss: 6.8095e-04 - val_acc: 0.8031
# Epoch 104/200
# 322928/322928 [==============================] - 10s 31us/step - loss: 7.4210e-04 - acc: 0.7841 - val_loss: 6.8121e-04 - val_acc: 0.8027
# Epoch 105/200
# 322928/322928 [==============================] - 10s 31us/step - loss: 7.4203e-04 - acc: 0.7849 - val_loss: 6.8112e-04 - val_acc: 0.7145
# Epoch 106/200
# 322928/322928 [==============================] - 10s 31us/step - loss: 7.4205e-04 - acc: 0.7855 - val_loss: 6.8105e-04 - val_acc: 0.7208
# Epoch 107/200
# 322928/322928 [==============================] - 10s 31us/step - loss: 7.4193e-04 - acc: 0.7852 - val_loss: 6.8100e-04 - val_acc: 0.8073
# Epoch 108/200
# 322928/322928 [==============================] - 10s 31us/step - loss: 7.4190e-04 - acc: 0.7852 - val_loss: 6.8101e-04 - val_acc: 0.7335
# --- AE spent 1047.1823439598083 seconds ---

# %%
best_loss_value_ae_siglin_adam_logcosh = plot_hist_auto(hist_ae_siglin_adam_logcosh, './Figures/hist_ae_siglin_adam_logcosh'+str(dsnum)+'.png')
# Out:
# Best loss value: 0.0007418981791673492

# %%
ae_sigmoid_adam_mse,enc_train_x_asam,enc_test_x_asam = ae(factor_enc_dim = 1.5,
                                                          enc_activation = 'relu',
                                                          dec_activation = 'sigmoid',
                                                          optimizer='Adam',
                                                          loss='mean_squared_error')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 66)                0
# _________________________________________________________________
# encoded_bottle_neck (Dense)  (None, 44)                2948
# _________________________________________________________________
# dense_3 (Dense)              (None, 66)                2970
# =================================================================
# Total params: 5,918
# Trainable params: 5,918
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#ae_sigmoid_adam_mse = load_model('ae_sigmoid_adam_mse_redds10bal.h5')

# %%
hist_ae_sigmoid_adam_mse = fit_ae(checkpoint_file = "ae_sigmoid_adam_mse_redds"+str(dsnum)+"bal.h5",
                                  autoencoder = ae_sigmoid_adam_mse, 
                                  epochs = 200, 
                                  batch_size = batch_size,
                                  shuffle = False)
# Out:
# Wed Jun 12 13:53:08 2019
# Train on 322928 samples, validate on 80732 samples
# Epoch 1/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 0.1669 - acc: 0.1980 - val_loss: 0.1535 - val_acc: 0.2202
# Epoch 2/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 0.1557 - acc: 0.1797 - val_loss: 0.1531 - val_acc: 0.1592
# Epoch 3/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 0.1553 - acc: 0.1451 - val_loss: 0.1530 - val_acc: 0.1366
# Epoch 4/200
# 322928/322928 [==============================] - 11s 33us/step - loss: 0.1553 - acc: 0.1435 - val_loss: 0.1530 - val_acc: 0.1479
# Epoch 5/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 0.1553 - acc: 0.1586 - val_loss: 0.1530 - val_acc: 0.1641
# Epoch 6/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 0.1553 - acc: 0.1725 - val_loss: 0.1530 - val_acc: 0.1745
# Epoch 7/200
# 322928/322928 [==============================] - 10s 31us/step - loss: 0.1553 - acc: 0.1775 - val_loss: 0.1530 - val_acc: 0.1734
# Epoch 8/200
# 322928/322928 [==============================] - 10s 31us/step - loss: 0
# 322928/322928 [==============================] - 11s 35us/step - loss: 0.1553 - acc: 0.1883 - val_loss: 0.1530 - val_acc: 0.1885
# Epoch 65/200
# 322928/322928 [==============================] - 11s 35us/step - loss: 0.1553 - acc: 0.1900 - val_loss: 0.1530 - val_acc: 0.1902
# Epoch 66/200
# 322928/322928 [==============================] - 11s 35us/step - loss: 0.1553 - acc: 0.1905 - val_loss: 0.1530 - val_acc: 0.1897
# Epoch 67/200
# 322928/322928 [==============================] - 12s 36us/step - loss: 0.1553 - acc: 0.1907 - val_loss: 0.1530 - val_acc: 0.1914
# Epoch 68/200
# 322928/322928 [==============================] - 11s 34us/step - loss: 0.1553 - acc: 0.1912 - val_loss: 0.1530 - val_acc: 0.1924
# Epoch 69/200
# 322928/322928 [==============================] - 11s 35us/step - loss: 0.1553 - acc: 0.1921 - val_loss: 0.1530 - val_acc: 0.1916
# Epoch 70/200
# 322928/322928 [==============================] - 11s 34us/step - loss: 0.1553 - acc: 0.1920 - val_loss: 0.1530 - val_acc: 0.1912
# Epoch 71/200
# 322928/322928 [==============================] - 11s 35us/step - loss: 0.1553 - acc: 0.1912 - val_loss: 0.1530 - val_acc: 0.1911
# Epoch 72/200
# 322928/322928 [==============================] - 11s 35us/step - loss: 0.1553 - acc: 0.1924 - val_loss: 0.1530 - val_acc: 0.1887
# Epoch 73/200
# 322928/322928 [==============================] - 11s 34us/step - loss: 0.1553 - acc: 0.1887 - val_loss: 0.1530 - val_acc: 0.1878
# --- AE spent 735.0309698581696 seconds ---

# %%
best_loss_value_ae_sigmoid_adam_mse  = plot_hist_auto(hist_ae_sigmoid_adam_mse, './Figures/hist_ae_sigmoid_adam_mse.png')
# Out:
# Best loss value: 0.15528595192022984

# %%
ae_sigsig_adam_logcosh,enc_train_x_assal,enc_test_x_assal = ae(factor_enc_dim = 1.5,
                                                          enc_activation = 'sigmoid',
                                                          dec_activation = 'sigmoid',
                                                          optimizer='Adam',
                                                          loss='logcosh')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 66)                0
# _________________________________________________________________
# encoded_bottle_neck (Dense)  (None, 44)                2948
# _________________________________________________________________
# dense_4 (Dense)              (None, 66)                2970
# =================================================================
# Total params: 5,918
# Trainable params: 5,918
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#ae_sigsig_adam_logcosh = load_model('ae_sigsig_adam_logcosh_redds10bal.h5')

# %%
hist_ae_sigsig_adam_logcosh = fit_ae(checkpoint_file = "ae_sigsig_adam_logcosh_redds"+str(dsnum)+"bal.h5",
                                  autoencoder = ae_sigsig_adam_logcosh, 
                                  epochs = 200, 
                                  batch_size = batch_size,
                                  shuffle = False)
# Out:
# Wed Jun 12 14:05:27 2019
# Train on 322928 samples, validate on 80732 samples
# Epoch 1/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 0.0665 - acc: 0.2593 - val_loss: 0.0563 - val_acc: 0.3233
# Epoch 2/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 0.0539 - acc: 0.3175 - val_loss: 0.0525 - val_acc: 0.2960
# Epoch 3/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 0.0524 - acc: 0.2714 - val_loss: 0.0522 - val_acc: 0.2358
# Epoch 4/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 0.0522 - acc: 0.2033 - val_loss: 0.0521 - val_acc: 0.1743
# Epoch 5/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 0.
200
# 322928/322928 [==============================] - 10s 30us/step - loss: 0.0521 - acc: 0.2163 - val_loss: 0.0520 - val_acc: 0.2174
# Epoch 191/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 0.0521 - acc: 0.2173 - val_loss: 0.0520 - val_acc: 0.2184
# Epoch 192/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 0.0521 - acc: 0.2188 - val_loss: 0.0520 - val_acc: 0.2216
# Epoch 193/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 0.0521 - acc: 0.2198 - val_loss: 0.0520 - val_acc: 0.2217
# Epoch 194/200
# 322928/322928 [==============================] - 9s 29us/step - loss: 0.0521 - acc: 0.2210 - val_loss: 0.0520 - val_acc: 0.2221
# Epoch 195/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 0.0521 - acc: 0.2216 - val_loss: 0.0520 - val_acc: 0.2240
# Epoch 196/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 0.0521 - acc: 0.2225 - val_loss: 0.0520 - val_acc: 0.2240
# Epoch 197/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 0.0521 - acc: 0.2239 - val_loss: 0.0520 - val_acc: 0.2254
# Epoch 198/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 0.0521 - acc: 0.2244 - val_loss: 0.0520 - val_acc: 0.2260
# Epoch 199/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 0.0521 - acc: 0.2251 - val_loss: 0.0520 - val_acc: 0.2266
# Epoch 200/200
# 322928/322928 [==============================] - 10s 30us/step - loss: 0.0521 - acc: 0.2262 - val_loss: 0.0520 - val_acc: 0.2277
# --- AE spent 1961.8439247608185 seconds ---

# %%
best_loss_value_ae_sigsig_adam_logcosh  = plot_hist_auto(hist_ae_sigsig_adam_logcosh, './Figures/hist_ae_sigsig_adam_logcosh'+str(dsnum)+'.png')
# Out:
# Best loss value: 0.052088021878408726

# %%
spae_sigmoid_adam_mse,enc_train_x_spsam,enc_test_x_spsam = spae(factor_enc_dim = 1.5,
                                                          enc_activation = 'relu',
                                                          dec_activation = 'sigmoid',
                                                          optimizer='Adam',
                                                          loss='mean_squared_error')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 66)                0
# _________________________________________________________________
# encoded_bottle_neck (Dense)  (None, 44)                2948
# _________________________________________________________________
# dense_33 (Dense)             (None, 66)                2970
# =================================================================
# Total params: 5,918
# Trainable params: 5,918
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#spae_sigmoid_adam_mse = load_model('spae_sigmoid_adam_mse_redds20bal.h5')

# %%
hist_spae_sigmoid_adam_mse = fit_ae(checkpoint_file = "spae_sigmoid_adam_mse_redds"+str(dsnum)+"bal.h5",
                                  autoencoder = spae_sigmoid_adam_mse, 
                                  epochs = 200, 
                                  batch_size = batch_size,
                                  shuffle = False)
# Out:
# Thu Jun 13 11:40:23 2019
# Train on 322928 samples, validate on 80732 samples
# Epoch 1/200
# 322928/322928 [==============================] - 14s 42us/step - loss: 0.2304 - acc: 0.1954 - val_loss: 0.2000 - val_acc: 0.2509
# Epoch 2/200
# 322928/322928 [==============================] - 13s 41us/step - loss: 0.1944 - acc: 0.2344 - val_loss: 0.1856 - val_acc: 0.1975
# Epoch 3/200
# 322928/322928 [==============================] - 13s 41us/step - loss: 0.1838 - acc: 0.1795 - val_loss: 0.1781 - val_acc: 0.1780
# Epoch 4/200
# 322928/322928 [==============================] - 13s 40us/step - loss: 0.1781 - acc: 0.1698 - val_loss: 0.1738 - val_acc: 0.1767
# Epoch 5/200
# 322928/322928 [==============================] - 13s 41us/step - loss: 0.1746 - acc: 0.1685 - val_loss: 0.1710 - val_acc: 0.1677
# Epoch 6/200
# 322928/322928 [==============================] - 13s 41us/step - loss: 0.1722 - acc: 0.1707 - val_loss: 0.1689 - val_acc: 0.1718
    'loss_value_ae_sigmoid_adam_logcosh': best_loss_value_ae_sigmoid_adam_logcosh,
    'loss_value_ae_sigmoid_adam_mse': best_loss_value_ae_sigmoid_adam_mse,
    'loss_value_ae_siglin_adam_logcosh': best_loss_value_ae_siglin_adam_logcosh,
    'loss_value_ae_sigsig_adam_logcosh': best_loss_value_ae_sigsig_adam_logcosh,
    'loss_value_spae_sigmoid_adam_mse': best_loss_value_spae_sigmoid_adam_mse
    }

# %%
loss_valueDict
# Out:
# {'loss_value_ae_sigmoid_adam_logcosh': 0.052111386396745764,
#  'loss_value_ae_sigmoid_adam_mse': 0.15528595192022984,
#  'loss_value_ae_siglin_adam_logcosh': 0.0007418981791673492,
#  'loss_value_ae_sigsig_adam_logcosh': 0.052088021878408726,
#  'loss_value_spae_sigmoid_adam_mse': 0.16108246017031486}

# %%
print(enc_train_x_asal.shape)
print(enc_test_x_asal.shape)

print(enc_train_x_asam.shape)
print(enc_test_x_asam.shape)

print(enc_train_x_aslal.shape)
print(enc_test_x_aslal.shape)  

print(enc_train_x_assal.shape)
print(enc_test_x_assal.shape)

print(enc_train_x_spsam.shape)
print(enc_test_x_spsam.shape)
# Out:
# (322928, 44)
# (100916, 44)
# (322928, 44)
# (100916, 44)
# (322928, 44)
# (100916, 44)
# (322928, 44)
# (100916, 44)
# (322928, 44)
# (100916, 44)

# %%
ann36n_unisoftsigbinlosadam = ann_1h_36n(neurons=neurons,
                                      encoded_train_x=enc_train_x_asal,
                                      init_mode='uniform',
                                      activation_input='softsign',
                                      weight_constraint=5,
                                      dropout_rate=0.0,
                                      activation_output='sigmoid',
                                      loss='binary_crossentropy',
                                      optimizer='Adam')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 66)                2970
# _________________________________________________________________
# dense_6 (Dense)              (None, 50)                3350
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 50)                200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 6,571
# Trainable params: 6,471
# Non-trainable params: 100
# _________________________________________________________________
# None

# %%
hist_ann36n_unisoftsigbinlosadam = ann_fit(checkpoint_file = "ann36n_unisoftsigbinlosadam_redds"+str(dsnum)+"bal.h5",
                                        ann = ann36n_unisoftsigbinlosadam,
                                        enc_train_x = enc_train_x_asal,
                                        train_y = train_y,
                                        epochs = 200,
                                        shuffle = True,
                                        batch_size = batch_size)
# Out:
# Wed Jun 12 15:01:31 2019
# Train on 258342 samples, validate on 64586 samples
# Epoch 1/200
# 258342/258342 [==============================] - 15s 57us/step - loss: 0.3337 - acc: 0.8517 - val_loss: 0.2142 - val_acc: 0.9109
# Epoch 2/200
# 258342/258342 [==============================] - 14s 55us/step - loss: 0.1975 - acc: 0.9172 - val_loss: 0.1696 - val_acc: 0.9282
# Epoch 3/200
# 258342/258342 [==============================] - 14s 55us/step - loss: 0.1689 - acc: 0.9288 - val_loss: 0.1648 - val_acc: 0.9261
# Epoch 4/200
# 258342/258342 [==============================] - 14s 56us/step - loss: 0.1496 - acc: 0.9358 - val_loss: 0.1166 - val_acc: 0.9515
# Epoch 5/200
# 258342/258342 [==============================] - 15s 57us/step - loss: 0.1373 - acc: 0.9406 - val_loss: 0.1172 - val_acc: 0.9510
# Epoch 6/200
200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.0655 - acc: 0.9707 - val_loss: 0.0585 - val_acc: 0.9742
# Epoch 30/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.0648 - acc: 0.9715 - val_loss: 0.0505 - val_acc: 0.9765
# Epoch 31/200
# 258342/258342 [==============================] - 15s 60us/step - loss: 0.0630 - acc: 0.9722 - val_loss: 0.0570 - val_acc: 0.9748
# Epoch 32/200
# 258342/258342 [==============================] - 15s 60us/step - loss: 0.0623 - acc: 0.9724 - val_loss: 0.0495 - val_acc: 0.9781
# Epoch 33/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.0617 - acc: 0.9727 - val_loss: 0.0487 - val_acc: 0.9801
# Epoch 34/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.0594 - acc: 0.9737 - val_loss: 0.0605 - val_acc: 0.9728
# Epoch 35/200
# 258342/258342 [==============================] - 15s 60us/step - loss: 0.0594 - acc: 0.9737 - val_loss: 0.0640 - val_acc: 0.9730
# Epoch 36/200
# 258342/258342 [==============================] - 16s 60us/step - loss: 0.0592 - acc: 0.9739 - val_loss: 0.0519 - val_acc: 0.9764
# Epoch 37/200
# 258342/258342 [==============================] - 16s 60us/step - loss: 0.0569 - acc: 0.9751 - val_loss: 0.0520 - val_acc: 0.9760
# Epoch 38/200
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.0569 - acc: 0.9751 - val_loss: 0.0440 - val_acc: 0.9798
# Epoch 39/200
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.0564 - acc: 0.9756 - val_loss: 0.0517 - val_acc: 0.9784
# Epoch 40/200
# 258342/258342 [==============================] - 16s 62us/step - loss: 0.0553 - acc: 0.9755 - val_loss: 0.0505 - val_acc: 0.9781
# Epoch 41/200
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.0544 - acc: 0.9762 - val_loss: 0.0459 - val_acc: 0.9803
# Epoch 42/200
# 258342/258342 [==============================] - 16s 62us/step - loss: 0.0540 - acc: 0.9763 - val_loss: 0.0490 - val_acc: 0.9771
# Epoch 43/200
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.0527 - acc: 0.9769 - val_loss: 0.0476 - val_acc: 0.9775
# --- ANN spent 658.5976541042328 seconds ---

# %%
best_loss_value_ann36n_unisoftsigbinlosadam = plot_hist_auto(hist_ann36n_unisoftsigbinlosadam, './Figures/ann36_unisoftsigbinlosadam'+str(dsnum)+'.png')
# Out:
# Best loss value: 0.052652317742995294

# %%
pred_ann36n_prob_unisoftsigbinlosadam, pred_ann36n_01_unisoftsigbinlosadam = ann_predict(ann36n_unisoftsigbinlosadam,enc_test_x_asal)
# Out:
# Overall accuracy of Neural Network model: 0.9774366800110983
#               precision    recall  f1-score   support
#
#            0     0.9931    0.9619    0.9772     50813
#            1     0.9625    0.9932    0.9776     50103
#
#    micro avg     0.9774    0.9774    0.9774    100916
#    macro avg     0.9778    0.9775    0.9774    100916
# weighted avg     0.9779    0.9774    0.9774    100916

# %%
plot_roc_cm(pred_ann36n_01_unisoftsigbinlosadam, pred_ann36n_01_unisoftsigbinlosadam, './Figures/ROC_ann36n_unisoftsigbinlosadam_redds'+str(dsnum)+'bal.png', './Figures/CM_ann36n_unisoftsigbinlosadam_redds'+str(dsnum)+'bal.png')

# %%
ann36n_unisoftsigbinlosadam2 = ann_1h_36n(neurons=neurons,
                                      encoded_train_x=enc_train_x_asam,
                                      init_mode='uniform',
                                      activation_input='softsign',
                                      weight_constraint=5,
                                      dropout_rate=0.0,
                                      activation_output='sigmoid',
                                      loss='binary_crossentropy',
                                      optimizer='Adam')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_11 (Dense)             (None, 66)                2970
# _________________________________________________________________
# dense_12 (Dense)             (None, 50)                3350
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 50)                200
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 6,571
# Trainable params: 6,471
# Non-trainable params: 100
# _________________________________________________________________
# None

# %%
hist_ann36n_unisoftsigbinlosadam2 = ann_fit(checkpoint_file = "ann36n_unisoftsigbinlosadam2_redds"+str(dsnum)+"bal.h5",
                                        ann = ann36n_unisoftsigbinlosadam2,
                                        enc_train_x = enc_train_x_asam,
                                        train_y = train_y,
                                        epochs = 200,
                                        shuffle = True,
                                        batch_size = batch_size)
# Out:
# Wed Jun 12 15:22:59 2019
# Train on 258342 samples, validate on 64586 samples
# Epoch 1/200
# 258342/258342 [==============================] - 16s 60us/step - loss: 0.3280 - acc: 0.8562 - val_loss: 0.2156 - val_acc: 0.9137
# Epoch 2/200
# 258342/258342 [==============================] - 15s 58us/step - loss: 0.1912 - acc: 0.9225 - val_loss: 0.1601 - val_acc: 0.9358
# Epoch 3/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.1588 - acc: 0.9346 - val_loss: 0.1292 - val_acc: 0.9472
# Epoch 4/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.1401 - acc: 0.9417 - val_loss: 0.1237 - val_acc: 0.9496
# Epoch 5/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.1292 - acc: 0.9459 - val_loss: 0.1210 - val_acc: 0.9467
# Epoch 6/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.1201 - acc: 0.9497 - val_loss: 0.1073 - val_acc: 0.9536
# Epoch 7/200
# 258342/258342 [==============================] - 15s 60us/step - loss: 0.1118 - acc: 0.9523 - val_loss: 0.1008 - val_acc: 0.9574
# Epoch 8/200
# 258342/258342 [==============================] - 15s 60us/step - loss: 0.1071 - acc: 0.9537 - val_loss: 0.0949 - val_acc: 0.9597
# Epoch 9/200
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.1019 - acc: 0.9567 - val_loss: 0.0876 - val_acc: 0.9631
# Epoch 10/200
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.0976 - acc: 0.9583 - val_loss: 0.0835 - val_acc: 0.9660
# Epoch 11/200
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.0934 - acc: 0.9597 - val_loss: 0.0760 - val_acc: 0.9688
# Epoch 12/200
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.0891 - acc: 0.9617 - val_loss: 0.0768 - val_acc: 0.9672
# Epoch 13/200
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.0871 - acc: 0.9628 - val_loss: 0.0759 - val_acc: 0.9696
# Epoch 14/200
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.0833 - acc: 0.9643 - val_loss: 0.0692 - val_acc: 0.9707
# Epoch 15/200
# 258342/258342 [==============================] - 16s 62us/step - loss: 0.0809 - acc: 0.9660 - val_loss: 0.0749 - val_acc: 0.9667
# Epoch 16/200
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.0778 - acc: 0.9671 - val_loss: 0.0632 - val_acc: 0.9720
# Epoch 17/200
# 258342/258342 [==============================] - 16s 62us/step - loss: 0.0759 - acc: 0.9679 - val_loss: 0.0612 - val_acc: 0.9726
# Epoch 18/200
# 258342/258342 [==============================] - 16s 62us/step - loss: 0.0736 - acc: 0.9687 - val_loss: 0.0693 - val_acc: 0.9712
# Epoch 19/200
# 258342/258342 [==============================] - 16s 62us/step - loss: 0.0710 - acc: 0.9702 - val_loss: 0.0576 - val_acc: 0.9777
# Epoch 20/200
# 258342/258342 [==============================] - 16s 62us/step - loss: 0.0676 - acc: 0.9717 - val_loss: 0.0589 - val_acc: 0.9755
# Epoch 21/200
# 258342/258342 [==============================] - 16s 62us/step - loss: 0.0677 - acc: 0.9713 - val_loss: 0.0519 - val_acc: 0.9781
# Epoch 22/200
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.0653 - acc: 0.9724 - val_loss: 0.0569 - val_acc: 0.9754
# Epoch 23/200
# 258342/258342 [==============================] - 16s 62us/step - loss: 0.0623 - acc: 0.9741 - val_loss: 0.0538 - val_acc: 0.9764
# Epoch 24/200
# 258342/258342 [==============================] - 16s 63us/step - loss: 0.0625 - acc: 0.9735 - val_loss: 0.0536 - val_acc: 0.9780
# Epoch 25/200
# 258342/258342 [==============================] - 16s 63us/step - loss: 0.0606 - acc: 0.9749 - val_loss: 0.0519 - val_acc: 0.9770
# Epoch 26/200
# 258342/258342 [==============================] - 16s 63us/step - loss: 0.0576 - acc: 0.9757 - val_loss: 0.0545 - val_acc: 0.9791
# --- ANN spent 409.2265303134918 seconds ---

# %%
best_loss_value_ann36n_unisoftsigbinlosadam2 = plot_hist_auto(hist_ann36n_unisoftsigbinlosadam2, './Figures/ann36_unisoftsigbinlosadam2'+str(dsnum)+'.png')
# Out:
# Best loss value: 0.057642073749549466

# %%
pred_ann36n_prob_unisoftsigbinlosadam, pred_ann36n_01_unisoftsigbinlosadam2 = ann_predict(ann36n_unisoftsigbinlosadam2,enc_test_x_asam)
# Out:
# Overall accuracy of Neural Network model: 0.9787546077926196
#               precision    recall  f1-score   support
#
#            0     0.9915    0.9661    0.9786     50813
#            1     0.9665    0.9916    0.9789     50103
#
#    micro avg     0.9788    0.9788    0.9788    100916
#    macro avg     0.9790    0.9788    0.9788    100916
# weighted avg     0.9791    0.9788    0.9788    100916

# %%
plot_roc_cm(pred_ann36n_01_unisoftsigbinlosadam, pred_ann36n_01_unisoftsigbinlosadam, './Figures/ROC_ann36n_unisoftsigbinlosadam_redds'+str(dsnum)+'bal.png', './Figures/CM_ann36n_unisoftsigbinlosadam_redds'+str(dsnum)+'bal.png')

# %%
ann_2h_unisoftsigbinlosadam = ann_2h(neurons=neurons,
                                      encoded_train_x=enc_train_x_asam,
                                      init_mode='uniform',
                                      activation_input='softsign',
                                      weight_constraint=5,
                                      dropout_rate=0.0,
                                      activation_output='sigmoid',
                                      loss='binary_crossentropy',
                                      optimizer='Adam')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 66)                2970
# _________________________________________________________________
# dense_15 (Dense)             (None, 50)                3350
# _________________________________________________________________
# dense_16 (Dense)             (None, 33)                1683
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 33)                132
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 33)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 34
# =================================================================
# Total params: 8,169
# Trainable params: 8,103
# Non-trainable params: 66
# _________________________________________________________________
# None

# %%
hist_ann_2h_unisoftsigbinlosadam = ann_fit(checkpoint_file = "ann_2h_unisoftsigbinlosadam_redds"+str(dsnum)+"bal.h5",
                                        ann = ann_2h_unisoftsigbinlosadam,
                                        enc_train_x = enc_train_x_asam,
                                        train_y = train_y,
                                        epochs = 200,
                                        shuffle = True,
                                        batch_size = batch_size)
# Out:
# Wed Jun 12 15:29:51 2019
# Train on 258342 samples, validate on 64586 samples
# Epoch 1/200
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.2833 - acc: 0.8695 - val_loss: 0.1635 - val_acc: 0.9307
# Epoch 2/200
# 258342/258342 [==============================] - 15s 58us/step - loss: 0.1435 - acc: 0.9385 - val_loss: 0.1204 - val_acc: 0.9458
# Epoch 3/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.1144 - acc: 0.9511 - val_loss: 0.1111 - val_acc: 0.9527
# Epoch 4/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.1005 - acc: 0.9570 - val_loss: 0.0875 - val_acc: 0.9599
# Epoch 5/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.0897 - acc: 0.9613 - val_loss: 0.0798 - val_acc: 0.9648
# Epoch 6/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.0816 - acc: 0.9649 - val_loss: 0.0661 - val_acc: 0.9710
# Epoch 7/200
# 258342/258342 [==============================] - 15s 60us/step - loss: 0.0751 - acc: 0.9676 - val_loss: 0.0659 - val_acc: 0.9741
# Epoch 8/200
# 258342/258342 [==============================] - 15s 60us/step - loss: 0.0710 - acc: 0.9697 - val_loss: 0.0763 - val_acc: 0.9683
# Epoch 9/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.0673 - acc: 0.9714 - val_loss: 0.0751 - val_acc: 0.9713
# Epoch 10/200
# 258342/258342 [==============================] - 15s 60us/step - loss: 0.0633 - acc: 0.9733 - val_loss: 0.0579 - val_acc: 0.9769
# Epoch 11/200
# 258342/258342 [==============================] - 15s 60us/step - loss: 0.0608 - acc: 0.9746 - val_loss: 0.0536 - val_acc: 0.9759
# Epoch 12/200
# 258342/258342 [==============================] - 16s 60us/step - loss: 0.0571 - acc: 0.9760 - val_loss: 0.0470 - val_acc: 0.9806
# Epoch 13/200
# 258342/258342 [==============================] - 16s 60us/step - loss: 0.0553 - acc: 0.9766 - val_loss: 0.0431 - val_acc: 0.9830
# Epoch 14/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.0525 - acc: 0.9777 - val_loss: 0.0490 - val_acc: 0.9782
# Epoch 15/200
# 258342/258342 [==============================] - 15s 60us/step - loss: 0.0509 - acc: 0.9787 - val_loss: 0.0408 - val_acc: 0.9838
# Epoch 16/200
# 258342/258342 [==============================] - 15s 60us/step - loss: 0.0496 - acc: 0.9792 - val_loss: 0.0599 - val_acc: 0.9771
# Epoch 17/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.0271 - acc: 0.9889 - val_loss: 0.0198 - val_acc: 0.9919
# Epoch 43/200
# 258342/258342 [==============================] - 15s 60us/step - loss: 0.0266 - acc: 0.9892 - val_loss: 0.0330 - val_acc: 0.9883
# Epoch 44/200
# 258342/258342 [==============================] - 15s 60us/step - loss: 0.0258 - acc: 0.9892 - val_loss: 0.0206 - val_acc: 0.9917
# Epoch 45/200
# 258342/258342 [==============================] - 15s 60us/step - loss: 0.0253 - acc: 0.9896 - val_loss: 0.0247 - val_acc: 0.9900
# Epoch 46/200
# 258342/258342 [==============================] - 15s 60us/step - loss: 0.0259 - acc: 0.9895 - val_loss: 0.0217 - val_acc: 0.9907
# Epoch 47/200
# 258342/258342 [==============================] - 16s 60us/step - loss: 0.0238 - acc: 0.9901 - val_loss: 0.0197 - val_acc: 0.9922
# Epoch 48/200
# 258342/258342 [==============================] - 16s 60us/step - loss: 0.0248 - acc: 0.9898 - val_loss: 0.0185 - val_acc: 0.9924
# Epoch 49/200
# 258342/258342 [==============================] - 16s 60us/step - loss: 0.0238 - acc: 0.9903 - val_loss: 0.0259 - val_acc: 0.9913
# Epoch 50/200
# 258342/258342 [==============================] - 15s 60us/step - loss: 0.0239 - acc: 0.9904 - val_loss: 0.0175 - val_acc: 0.9924
# Epoch 51/200
# 258342/258342 [==============================] - 16s 60us/step - loss: 0.0237 - acc: 0.9905 - val_loss: 0.0232 - val_acc: 0.9901
# Epoch 52/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.0227 - acc: 0.9907 - val_loss: 0.0186 - val_acc: 0.9913
# Epoch 53/200
# 258342/258342 [==============================] - 15s 60us/step - loss: 0.0230 - acc: 0.9907 - val_loss: 0.0190 - val_acc: 0.9931
# Epoch 54/200
# 258342/258342 [==============================] - 15s 60us/step - loss: 0.0235 - acc: 0.9905 - val_loss: 0.0216 - val_acc: 0.9914
# Epoch 55/200
# 258342/258342 [==============================] - 15s 60us/step - loss: 0.0238 - acc: 0.9902 - val_loss: 0.0210 - val_acc: 0.9920
# --- ANN spent 847.8624029159546 seconds ---

# %%
# hist_ann_2h_unisoftsigbinlosadam.model.get_weights()

# %%
best_loss_value_ann_2h_unisoftsigbinlosadam = plot_hist_auto(hist_ann_2h_unisoftsigbinlosadam, './Figures/ann_2h_unisoftsigbinlosadam.png')
# Out:
# Best loss value: 0.023809212874223135

# %%
pred_ann_2h_prob_unisoftsigbinlosadam, pred_ann_2h_01_unisoftsigbinlosadam = ann_predict(ann_2h_unisoftsigbinlosadam,enc_test_x_asam)
# Out:
# Overall accuracy of Neural Network model: 0.9915077886559118
#               precision    recall  f1-score   support
#
#            0     0.9950    0.9881    0.9915     50813
#            1     0.9880    0.9950    0.9915     50103
#
#    micro avg     0.9915    0.9915    0.9915    100916
#    macro avg     0.9915    0.9915    0.9915    100916
# weighted avg     0.9915    0.9915    0.9915    100916

# %%
plot_roc_cm(pred_ann_2h_01_unisoftsigbinlosadam, pred_ann_2h_01_unisoftsigbinlosadam, './Figures/ROC_ann_2h_unisoftsigbinlosadam_redds'+str(dsnum)+'bal.png', './Figures/CM_ann_2h_unisoftsigbinlosadam_redds'+str(dsnum)+'bal.png')

# %%
ann_2h_unisoftsigbinlosadam2 = ann_2h_(neurons=neurons,
                                      encoded_train_x=enc_train_x_asal,
#                                       init_mode='glorot_uniform',
                                       init_mode='VarianceScaling',
#                                       activation_input='softsign',
                                      activation_input='relu',
#                                       weight_constraint=5,
                                      dropout_rate=0.0,
                                      activation_output='sigmoid',
                                      loss='binary_crossentropy',
                                      lr=0.05)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 66)                2970
# _________________________________________________________________
# dense_19 (Dense)             (None, 50)                3350
# _________________________________________________________________
# dense_20 (Dense)             (None, 33)                1683
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 33)                132
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 33)                0
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 34
# =================================================================
# Total params: 8,169
# Trainable params: 8,103
# Non-trainable params: 66
# _________________________________________________________________
# None

# %%
hist_ann_2h_unisoftsigbinlosadam2 = ann_fit(checkpoint_file = "ann_2h_unisoftsigbinlosadam2_redds"+str(dsnum)+"bal.h5",
                                        ann = ann_2h_unisoftsigbinlosadam2,
                                        enc_train_x = enc_train_x_asal,
                                        train_y = train_y,
                                        epochs = 200,
                                        shuffle = True,
                                        batch_size = batch_size)
# Out:
# Wed Jun 12 15:44:02 2019
# Train on 258342 samples, validate on 64586 samples
# Epoch 1/200
# 258342/258342 [==============================] - 16s 62us/step - loss: 0.3431 - acc: 0.8370 - val_loss: 0.2347 - val_acc: 0.8935
# Epoch 2/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.2131 - acc: 0.9031 - val_loss: 0.1749 - val_acc: 0.9212
# Epoch 3/200
# 258342/258342 [==============================] - 15s 58us/step - loss: 0.1967 - acc: 0.9065 - val_loss: 0.1745 - val_acc: 0.9152
# Epoch 4/200
# 258342/258342 [==============================] - 15s 58us/step - loss: 0.1739 - acc: 0.9187 - val_loss: 0.1379 - val_acc: 0.9347
# Epoch 5/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.1512 - acc: 0.9306 - val_loss: 0.1242 - val_acc: 0.9427
# Epoch 6/200
# 258342/258342 [==============================] - 15s 60us/step - loss: 0.1374 - acc: 0.9370 - val_loss: 0.1141 - val_acc: 0.9472
# Epoch 7/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.1274 - acc: 0.9424 - val_loss: 0.1032 - val_acc: 0.9518
# Epoch 8/200
# 258342/258342 [==============================] - 15s 60us/step - loss: 0.1199 - acc: 0.9461 - val_loss: 0.0971 - val_acc: 0.9558
# Epoch 9/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.1129 - acc: 0.9496 - val_loss: 0.1017 - val_acc: 0.9537
# Epoch 10/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.1092 - acc: 0.9513 - val_loss: 0.0921 - val_acc: 0.9585
# Epoch 11/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.1041 - acc: 0.9539 - val_loss: 0.0923 - val_acc: 0.9589
# Epoch 12/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.0998 - acc: 0.9558 - val_loss: 0.0989 - val_acc: 0.9541
# Epoch 13/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.1024 - acc: 0.9556 - val_loss: 0.0901 - val_acc: 0.9609
# Epoch 14/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.0934 - acc: 0.9591 - val_loss: 0.0844 - val_acc: 0.9624
# Epoch 15/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.0924 - acc: 0.9599 - val_loss: 0.0916 - val_acc: 0.9634
# Epoch 16/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.0899 - acc: 0.9607 - val_loss: 0.0820 - val_acc: 0.9638
# Epoch 17/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.0881 - acc: 0.9620 - val_loss: 0.0811 - val_acc: 0.9649
# Epoch 18/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.0891 - acc: 0.9622 - val_loss: 0.0752 - val_acc: 0.9654
# Epoch 19/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.0830 - acc: 0.9643 - val_loss: 0.0693 - val_acc: 0.9711
# Epoch 20/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.0827 - acc: 0.9646 - val_loss: 0.0710 - val_acc: 0.9695
# Epoch 21/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.0822 - acc: 0.9648 - val_loss: 0.0666 - val_acc: 0.9678
# Epoch 22/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.0846 - acc: 0.9640 - val_loss: 0.0844 - val_acc: 0.9621
# Epoch 23/200
# 258342/258342 [==============================] - 15s 58us/step - loss: 0.0793 - acc: 0.9659 - val_loss: 0.0875 - val_acc: 0.9624
# Epoch 24/200
# 258342/258342 [==============================] - 15s 58us/step - loss: 0.0794 - acc: 0.9658 - val_loss: 0.0767 - val_acc: 0.9664
# Epoch 25/200
# 258342/258342 [==============================] - 15s 58us/step - loss: 0.0779 - acc: 0.9669 - val_loss: 0.0696 - val_acc: 0.9720
# Epoch 26/200
# 258342/258342 [==============================] - 15s 59us/step - loss: 0.0767 - acc: 0.9673 - val_loss: 0.0691 - val_acc: 0.9697
# --- ANN spent 396.96870279312134 seconds ---

# %%
best_loss_value_ann_2h_unisoftsigbinlosadam2 = plot_hist_auto(hist_ann_2h_unisoftsigbinlosadam2, './Figures/ann_2h_unisoftsigbinlosadam2'+str(dsnum)+'.png')
# Out:
# Best loss value: 0.07671638879709135

# %%
pred_ann_2h_prob_unisoftsigbinlosadam2, pred_ann_2h_01_unisoftsigbinlosadam2 = ann_predict(ann_2h_unisoftsigbinlosadam2,enc_test_x_asal)
# Out:
# Overall accuracy of Neural Network model: 0.9702128502913314
#               precision    recall  f1-score   support
#
#            0     0.9857    0.9547    0.9699     50813
#            1     0.9555    0.9859    0.9705     50103
#
#    micro avg     0.9702    0.9702    0.9702    100916
#    macro avg     0.9706    0.9703    0.9702    100916
# weighted avg     0.9707    0.9702    0.9702    100916

# %%
plot_roc_cm(pred_ann_2h_01_unisoftsigbinlosadam2, pred_ann_2h_01_unisoftsigbinlosadam2, './Figures/ROC_ann_2h_unisoftsigbinlosadam2_redds'+str(dsnum)+'bal.png', './Figures/CM_ann_2h_unisoftsigbinlosadam2_redds'+str(dsnum)+'bal.png')

# %% [markdown]
# ### **BEST with ae encoding ---------------------------------**

# %%
ann_2h_unisoftsigbinlosadam3 = ann_2h(neurons=neurons,
                                      encoded_train_x=enc_train_x_asam,
                                      init_mode='uniform',
                                      activation_input='relu',
                                      weight_constraint=5,
                                      dropout_rate=0.0,
                                      activation_output='sigmoid',
                                      loss='binary_crossentropy',
                                      optimizer='Adam')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_22 (Dense)             (None, 66)                2970
# _________________________________________________________________
# dense_23 (Dense)             (None, 50)                3350
# _________________________________________________________________
# dense_24 (Dense)             (None, 33)                1683
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 33)                132
# _________________________________________________________________
# dropout_6 (Dropout)          (None,
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.0348 - acc: 0.9853 - val_loss: 0.0301 - val_acc: 0.9870
# Epoch 18/200
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.0331 - acc: 0.9861 - val_loss: 0.0455 - val_acc: 0.9854
# Epoch 19/200
# 258342/258342 [==============================] - 16s 60us/step - loss: 0.0325 - acc: 0.9865 - val_loss: 0.0254 - val_acc: 0.9897
# Epoch 20/200
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.0316 - acc: 0.9869 - val_loss: 0.0398 - val_acc: 0.9858
# Epoch 21/200
# 258342/258342 [==============================] - 16s 62us/step - loss: 0.0307 - acc: 0.9872 - val_loss: 0.0291 - val_acc: 0.9887
# Epoch 22/200
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.0297 - acc: 0.9875 - val_loss: 0.0302 - val_acc: 0.9878
# Epoch 23/200
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.0294 - acc: 0.9878 - val_loss: 0.0271 - val_acc: 0.9897
# Epoch 24/200
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.0279 - acc: 0.9885 - val_loss: 0.0279 - val_acc: 0.9905
# --- ANN spent 379.5373857021332 seconds ---

# %%
# hist_ann_2h_unisoftsigbinlosadam.model.get_weights()

# %%
best_loss_value_ann_2h_unisoftsigbinlosadam3 = plot_hist_auto(hist_ann_2h_unisoftsigbinlosadam3, './Figures/ann_2h_unisoftsigbinlosadam3'+str(dsnum)+'.png')
# Out:
# Best loss value: 0.0278899914933505

# %%
pred_ann_2h_prob_unisoftsigbinlosadam3, pred_ann_2h_01_unisoftsigbinlosadam3 = ann_predict(ann_2h_unisoftsigbinlosadam3,enc_test_x_asam)
# Out:
# Overall accuracy of Neural Network model: 0.9897340362281501
#               precision    recall  f1-score   support
#
#            0     0.9924    0.9872    0.9898     50813
#            1     0.9871    0.9923    0.9897     50103
#
#    micro avg     0.9897    0.9897    0.9897    100916
#    macro avg     0.9897    0.9898    0.9897    100916
# weighted avg     0.9897    0.9897    0.9897    100916

# %%
plot_roc_cm(pred_ann_2h_01_unisoftsigbinlosadam3, pred_ann_2h_01_unisoftsigbinlosadam3, './Figures/ROC_ann_2h_unisoftsigbinlosadam3_redds'+str(dsnum)+'bal.png', './Figures/CM_ann_2h_unisoftsigbinlosadam3_redds'+str(dsnum)+'bal.png')

# %% [markdown]
# ### **BEST with spae encoding ---------------------------------**

# %%
sp_ann_2h_unisoftsigbinlosadam = ann_2h(neurons=neurons,
                                      encoded_train_x=enc_train_x_spsam,
                                      init_mode='uniform',
                                      activation_input='relu',
                                      weight_constraint=5,
                                      dropout_rate=0.0,
                                      activation_output='sigmoid',
                                      loss='binary_crossentropy',
                                      optimizer='Adam')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_34 (Dense)             (None, 66)                2970
# _________________________________________________________________
# dense_35 (Dense)             (None, 50)                3350
# _________________________________________________________________
# dense_36 (Dense)             (None, 33)                1683
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 33)                132
# _________________________________________________________________
# dropout_9 (Dropout)          (None,
# Epoch 18/200
# 258342/258342 [==============================] - 19s 72us/step - loss: 0.0340 - acc: 0.9862 - val_loss: 0.0321 - val_acc: 0.9869
# Epoch 19/200
# 258342/258342 [==============================] - 19s 73us/step - loss: 0.0327 - acc: 0.9867 - val_loss: 0.0290 - val_acc: 0.9886
# Epoch 20/200
# 258342/258342 [==============================] - 19s 73us/step - loss: 0.0313 - acc: 0.9873 - val_loss: 0.0279 - val_acc: 0.9878
# Epoch 21/200
# 258342/258342 [==============================] - 18s 71us/step - loss: 0.0305 - acc: 0.9877 - val_loss: 0.0321 - val_acc: 0.9875
# Epoch 22/200
# 258342/258342 [==============================] - 16s 64us/step - loss: 0.0294 - acc: 0.9880 - val_loss: 0.0236 - val_acc: 0.9902
# Epoch 23/200
# 258342/258342 [==============================] - 17s 64us/step - loss: 0.0281 - acc: 0.9883 - val_loss: 0.0218 - val_acc: 0.9922
# Epoch 24/200
# 258342/258342 [==============================] - 16s 64us/step - loss: 0.0278 - acc: 0.9886 - val_loss: 0.0295 - val_acc: 0.9889
# Epoch 25/200
# 258342/258342 [==============================] - 16s 63us/step - loss: 0.0266 - acc: 0.9890 - val_loss: 0.0257 - val_acc: 0.9888
# Epoch 26/200
# 258342/258342 [==============================] - 16s 63us/step - loss: 0.0263 - acc: 0.9892 - val_loss: 0.0222 - val_acc: 0.9911
# Epoch 27/200
# 258342/258342 [==============================] - 16s 63us/step - loss: 0.0256 - acc: 0.9896 - val_loss: 0.0370 - val_acc: 0.9868
# Epoch 28/200
# 258342/258342 [==============================] - 16s 64us/step - loss: 0.0248 - acc: 0.9898 - val_loss: 0.0294 - val_acc: 0.9901
# --- ANN spent 499.5891408920288 seconds ---

# %%
# hist_ann_2h_unisoftsigbinlosadam.model.get_weights()

# %%
best_loss_value_sp_ann_2h_unisoftsigbinlosadam = plot_hist_auto(hist_sp_ann_2h_unisoftsigbinlosadam, './Figures/sp_ann_2h_unisoftsigbinlosadam'+str(dsnum)+'.png')
# Out:
# Best loss value: 0.02480970929580695

# %%
pred_sp_ann_2h_prob_unisoftsigbinlosadam, pred_sp_ann_2h_01_unisoftsigbinlosadam = ann_predict(sp_ann_2h_unisoftsigbinlosadam,enc_test_x_spsam)
# Out:
# Overall accuracy of Neural Network model: 0.9898232193111103
#               precision    recall  f1-score   support
#
#            0     0.9939    0.9859    0.9899     50813
#            1     0.9858    0.9939    0.9898     50103
#
#    micro avg     0.9898    0.9898    0.9898    100916
#    macro avg     0.9898    0.9899    0.9898    100916
# weighted avg     0.9899    0.9898    0.9898    100916

# %%
plot_roc_cm(pred_sp_ann_2h_01_unisoftsigbinlosadam, pred_sp_ann_2h_01_unisoftsigbinlosadam, './Figures/ROC_sp_ann_2h_unisoftsigbinlosadam_redds'+str(dsnum)+'bal.png', './Figures/CM_sp_ann_2h_unisoftsigbinlosadam_redds'+str(dsnum)+'bal.png')

# %%
ann_2h_unisoftsigbinlosadam4 = ann_2h(neurons=neurons,
                                      encoded_train_x=enc_train_x_asal,
                                      init_mode='uniform',
                                      activation_input='relu',
                                      weight_constraint=5,
                                      dropout_rate=0.0,
                                      activation_output='sigmoid',
                                      loss='binary_crossentropy',
                                      optimizer='Adam')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_26 (Dense)             (None, 66)                2970
# _________________________________________________________________
# dense_27 (Dense)             (None, 50)                3350
# _________________________________________________________________
# dense_28 (Dense)             (None, 33)                1683
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 33)                132
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 33)                0
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 34
# =================================================================
# Total params: 8,169
# Trainable params: 8,103
# Non-trainable params: 66
# _________________________________________________________________
# None

# %%
hist_ann_2h_unisoftsigbinlosadam4 = ann_fit(checkpoint_file = "ann_2h_unisoftsigbinlosadam4_redds"+str(dsnum)+"bal.h5",
                                        ann = ann_2h_unisoftsigbinlosadam4,
                                        enc_train_x = enc_train_x_asal,
                                        train_y = train_y,
                                        epochs = 200,
                                        shuffle = True,
                                        batch_size = batch_size)
# Out:
# Wed Jun 12 15:57:05 2019
# Train on 258342 samples, validate on 64586 samples
# Epoch 1/200
# 258342/258342 [==============================] - 17s 67us/step - loss: 0.2552 - acc: 0.8828 - val_loss: 0.1547 - val_acc: 0.9282
# Epoch 2/200
# 258342/258342 [==============================] - 17s 65us/step - loss: 0.1399 - acc: 0.9374 - val_loss: 0.1107 - val_acc: 0.9494
# Epoch 3/200
# 258342/258342 [==============================] - 17s 66us/step - loss: 0.1164 - acc: 0.9483 - val_loss: 0.1044 - val_acc: 0.9530
# Epoch 4/200
# 258342/258342 [==============================] - 17s 66us/step - loss: 0.1012 - acc: 0.9546 - val_loss: 0.0995 - val_acc: 0.9551
# Epoch 5/200
# 258342/258342 [==============================] - 17s 66us/step - loss: 0.0891 - acc: 0.9597 - val_loss: 0.0732 - val_acc: 0.9672
# Epoch 6/200
# 258342/258342 [==============================] - 17s 67us/step - loss: 0.0823 - acc: 0.9632 - val_loss: 0.0726 - val_acc: 0.9688
# Epoch 7/200
# 258342/258342 [==============================] - 18s 68us/step - loss: 0.0758 - acc: 0.9658 - val_loss: 0.0774 - val_acc: 0.9640
# Epoch 8/200
# 258342/258342 [==============================] - 18s 69us/step - loss: 0.0699 - acc: 0.9684 - val_loss: 0.0611 - val_acc: 0.9733
# Epoch 9/200
# 258342/258342 [==============================] - 18s 69us/step - loss: 0.0664 - acc: 0.9701 - val_loss: 0.0646 - val_acc: 0.9703
# Epoch 10/200
# 258342/258342 [==============================] - 18s 69us/step - loss: 0.0624 - acc: 0.9716 - val_loss: 0.0556 - val_acc: 0.9731
# Epoch 11/200
# 258342/258342 [==============================] - 18s 69us/step - loss: 0.0593 - acc: 0.9737 - val_loss: 0.0494 - val_acc: 0.9781
# Epoch 12/200
# 258342/258342 [==============================] - 18s 68us/step - loss: 0.0567 - acc: 0.9744 - val_loss: 0.0475 - val_acc: 0.9785
# Epoch 13/200
# 258342/258342 [==============================] - 18s 69us/step - loss: 0.0532 - acc: 0.9761 - val_loss: 0.0611 - val_acc: 0.9749
# Epoch 14/200
# 258342/258342 [==============================] - 18s 69us/step - loss: 0.0521 - acc: 0.9768 - val_loss: 0.0423 - val_acc: 0.9817
# Epoch 15/200
# 258342/258342 [==============================] - 18s 69us/step - loss: 0.0489 - acc: 0.9786 - val_loss: 0.0520 - val_acc: 0.9775
# Epoch 16/200
# 258342/258342 [==============================] - 18s 69us/step - loss: 0.0482 - acc: 0.9790 - val_loss: 0.0436 - val_acc: 0.9802
# Epoch 17/200
# 258342/258342 [==============================] - 18s 69us/step - loss: 0.0459 - acc: 0.9799 - val_loss: 0.0422 - val_acc: 0.9813
# Epoch 18/200
# 258342/258342 [==============================] - 18s 69us/step - loss: 0.0446 - acc: 0.9805 - val_loss: 0.0341 - val_acc: 0.9862
# Epoch 19/200
# 258342/258342 [==============================] - 18s 68us/step - loss: 0.0428 - acc: 0.9812 - val_loss: 0.0377 - val_acc: 0.9843
# Epoch 20/200
# 258342/258342 [==============================] - 18s 70us/step - loss: 0.0422 - acc: 0.9819 - val_loss: 0.0448 - val_acc: 0.9812
# Epoch 21/200
# 258342/258342 [==============================] - 18s 69us/step - loss: 0.0404 - acc: 0.9828 - val_loss: 0.0354 - val_acc: 0.9843
# Epoch 22/200
# 258342/258342 [==============================] - 18s 69us/step - loss: 0.0387 - acc: 0.9834 - val_loss: 0.0346 - val_acc: 0.9848
# Epoch 23/200
# 258342/258342 [==============================] - 17s 65us/step - loss: 0.0381 - acc: 0.9838 - val_loss: 0.0342 - val_acc: 0.9857
# --- ANN spent 404.0722393989563 seconds ---

# %%
# hist_ann_2h_unisoftsigbinlosadam.model.get_weights()

# %%
best_loss_value_ann_2h_unisoftsigbinlosadam4 = plot_hist_auto(hist_ann_2h_unisoftsigbinlosadam4, './Figures/ann_2h_unisoftsigbinlosadam4'+str(dsnum)+'.png')
# Out:
# Best loss value: 0.03810614454785907

# %%
pred_ann_2h_prob_unisoftsigbinlosadam4, pred_ann_2h_01_unisoftsigbinlosadam4 = ann_predict(ann_2h_unisoftsigbinlosadam4,enc_test_x_asal)
# Out:
# Overall accuracy of Neural Network model: 0.9859090728923064
#               precision    recall  f1-score   support
#
#            0     0.9912    0.9807    0.9859     50813
#            1     0.9807    0.9912    0.9859     50103
#
#    micro avg     0.9859    0.9859    0.9859    100916
#    macro avg     0.9859    0.9859    0.9859    100916
# weighted avg     0.9860    0.9859    0.9859    100916

# %%
plot_roc_cm(pred_ann_2h_01_unisoftsigbinlosadam4, pred_ann_2h_01_unisoftsigbinlosadam4, './Figures/ROC_ann_2h_unisoftsigbinlosadam4_redds'+str(dsnum)+'bal.png', './Figures/CM_ann_2h_unisoftsigbinlosadam4_redds'+str(dsnum)+'bal.png')

# %%
ann_24n_unisoftsigbinlosadam = ann_1h_24n(neurons=neurons,
                                      encoded_train_x=train_x,
                                      init_mode='uniform',
                                      activation_input='softsign',
                                      weight_constraint=5,
                                      dropout_rate=0.0,
                                      activation_output='sigmoid',
                                      loss='binary_crossentropy',
                                      optimizer='Adam')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 66)                4422
# _________________________________________________________________
# dense_31 (Dense)             (None, 50)                3350
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 50)                200
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 8,023
# Trainable params: 7,923
# Non-trainable params: 100
# _________________________________________________________________
# None

# %%
hist_ann_24n_unisoftsigbinlosadam = ann_fit(checkpoint_file = "ann_24n_unisoftsigbinlosadam_redds"+str(dsnum)+"bal.h5",
                                        ann = ann_24n_unisoftsigbinlosadam,
                                        enc_train_x = train_x,
                                        train_y = train_y,
                                        epochs = 200,
                                        shuffle = True,
                                        batch_size = batch_size)
# Out:
# Wed Jun 12 16:03:53 2019
# Train on 258342 samples, validate on 64586 samples
# Epoch 1/200
# 258342/258342 [==============================] - 17s 65us/step - loss: 0.2144 - acc: 0.9068 - val_loss: 0.1327 - val_acc: 0.9425
# Epoch 2/200
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.1212 - acc: 0.9477 - val_loss: 0.1099 - val_acc: 0.9557
# Epoch 3/200
# 258342/258342 [==============================] - 16s 61us/step - loss: 0.0943 - acc: 0.9595 - val_loss: 0.0716 - val_acc: 0.9685
# Epoch 4/200
# 258342/258342 [==============================] - 16s 62us/step - loss: 0.0760 - acc: 0.9682 - val_loss: 0.0599 - val_acc: 0.9749
# Epoch 5/200
# 258342/258342 [==============================] - 16s 64us/step - loss: 0.0655 - acc: 0.9728 - val_loss: 0.0604 - val_acc: 0.9752
# Epoch 6/200
# 258342/258342 [==============================] - 16s 62us/step - loss: 0.0573 - acc: 0.9763 - val_loss: 0.0435 - val_acc: 0.9814
# Epoch 7/200
# 258342/258342 [==============================] - 17s 64us/step - loss: 0.0528 - acc: 0.9782 - val_loss: 0.0385 - val_acc: 0.9857
# Epoch 8/200
# 258342/258342 [==============================] - 17s 67us/step - loss: 0.0484 - acc: 0.9800 - val_loss: 0.0433 - val_acc: 0.9819
# Epoch 9/200
# 258342/258342 [==============================] - 16s 63us/step - loss: 0.0477 - acc: 0.9806 - val_loss: 0.0391 - val_acc: 0.9821
# Epoch 10/200
# 258342/258342 [==============================] - 17s 66us/step - loss: 0.0441 - acc: 0.9818 - val_loss: 0.0321 - val_acc: 0.9887
# Epoch 11/200
# 258342/258342 [==============================] - 18s 70us/step - loss: 0.0425 - acc: 0.9827 - val_loss: 0.0317 - val_acc: 0.9861
# Epoch 12/200
# 258342/258342 [==============================] - 18s 69us/step - loss: 0.0390 - acc: 0.9841 - val_loss: 0.0316 - val_acc: 0.9880
# Epoch 13/200
# 258342/258342 [==============================] - 18s 70us/step - loss: 0.0371 - acc: 0.9850 - val_loss: 0.0265 - val_acc: 0.9904
# Epoch 14/200
# 258342/258342 [==============================] - 18s 70us/step - loss: 0.0356 - acc: 0.9858 - val_loss: 0.0316 - val_acc: 0.9880
# Epoch 15/200
# 258342/258342 [==============================] - 18s 69us/step - loss: 0.0337 - acc: 0.9865 - val_loss: 0.0251 - val_acc: 0.9892
# Epoch 16/200
# 258342/258342 [==============================] - 18s 70us/step - loss: 0.0333 - acc: 0.9867 - val_loss: 0.0507 - val_acc: 0.9819
# Epoch 17/200
# 258342/258342 [==============================] - 18s 70us/step - loss: 0.0303 - acc: 0.9880 - val_loss: 0.0274 - val_acc: 0.9891
# Epoch 18/200
# 258342/258342 [==============================] - 18s 70us/step - loss: 0.0303 - acc: 0.9885 - val_loss: 0.0277 - val_acc: 0.9892
# Epoch 19/200
# 258342/258342 [==============================] - 18s 69us/step - loss: 0.0291 - acc: 0.9886 - val_loss: 0.0260 - val_acc: 0.9894
# Epoch 20/200
# 258342/258342 [==============================] - 18s 70us/step - loss: 0.0267 - acc: 0.9898 - val_loss: 0.0354 - val_acc: 0.9867
# --- ANN spent 344.6270549297333 seconds ---

# %%
best_loss_value_ann_24n_unisoftsigbinlosadam = plot_hist_auto(hist_ann_24n_unisoftsigbinlosadam, './Figures/ann_24_unisoftsigbinlosadam'+str(dsnum)+'.png')
# Out:
# Best loss value: 0.026746195884415454

# %%
pred_ann_24n_prob_unisoftsigbinlosadam, pred_ann_24n_01_unisoftsigbinlosadam = ann_predict(ann_24n_unisoftsigbinlosadam,test_x)
# Out:
# Overall accuracy of Neural Network model: 0.9862261682983868
#               precision    recall  f1-score   support
#
#            0     0.9944    0.9782    0.9862     50813
#            1     0.9782    0.9944    0.9862     50103
#
#    micro avg     0.9862    0.9862    0.9862    100916
#    macro avg     0.9863    0.9863    0.9862    100916
# weighted avg     0.9864    0.9862    0.9862    100916

# %%
plot_roc_cm(pred_ann_24n_01_unisoftsigbinlosadam, pred_ann_24n_01_unisoftsigbinlosadam, './Figures/ROC_ann_24n_unisoftsigbinlosadam_redds'+str(dsnum)+'bal.png', './Figures/CM_ann_24n_unisoftsigbinlosadam_redds'+str(dsnum)+'bal.png')

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(n_estimators=300, 
                             criterion='gini', 
                             max_depth=16, 
#                              min_samples_split=2, 
                             #min_samples_leaf=1, 
                             max_features=0.3, 
                             #bootstrap=True,
                             oob_score=True,
                             random_state=23)

# %%
start_time = time.time()
print(time.ctime(start_time))

clf.fit(enc_train_x_asam, train_y)

pred_y_RF = cross_val_predict(estimator=clf,
                              X=np.array(enc_test_x_asam),
                              y=test_y,
                              cv=KFold(n_splits=5, random_state=23),
                              n_jobs=2)

elapsed_time = (time.time() - start_time)
print("--- %s seconds ---" %elapsed_time)

print(sm.classification_report(test_y, pred_y_RF,digits=4))
# Out:
# Wed Jun 12 16:09:41 2019
# --- 1139.6389245986938 seconds ---
#               precision    recall  f1-score   support
#
#            0     0.9966    0.9974    0.9970     50813
#            1     0.9973    0.9965    0.9969     50103
#
#    micro avg     0.9970    0.9970    0.9970    100916
#    macro avg     0.9970    0.9970    0.9970    100916
# weighted avg     0.9970    0.9970    0.9970    100916

# %%
plot_roc_cm(pred_y_RF, pred_y_RF, './Figures/ROC_rf_E100MaxfautoMaxdnoneBootT_redds'+str(dsnum)+'bal.png', './Figures/CM_rf_E100MaxfautoMaxdnoneBootT_redds'+str(dsnum)+'bal.png')
