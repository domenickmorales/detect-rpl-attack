# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
###################################
# TensorFlow wizardry
import tensorflow as tf
config = tf.ConfigProto()
 
# Don’t pre-allocate memory; allocate as-needed
config.gpu_options.allow_growth = True
 
# Only allow a total of half the GPU memory to be allocated
config.gpu_options.per_process_gpu_memory_fraction = 0.05
#gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.333)
 
# Create a session with the above options specified.
from keras import optimizers, regularizers
from keras.layers.normalization import BatchNormalization
from keras.utils import to_categorical
from keras.wrappers.scikit_learn import KerasClassifier
from keras import optimizers
from keras.constraints import maxnorm
from keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping

from keras.models import Sequential, Model, load_model
from keras.layers import Activation, Dense, Dropout, Input
from keras import backend as k

k.tensorflow_backend.set_session(tf.Session(config=config))
#k.tensorflow_backend.set_session(tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
###################################

# %%
#----------------------------------Import modules------------------------------
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score, roc_curve, auc
from sklearn import preprocessing
sns.set_style("whitegrid")
np.random.seed(23)
import time
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
import sklearn.metrics as sm
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_predict
from datetime import datetime 
import os.path

dsnum=20
verbose_level=1

# %%
if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device: /device:GPU:0

# %%
pathds = os.path.abspath('/home/user/01Code/00Datasets_final/00BalancedDS')
file_name = "HalfCloneID"+str(dsnum)+"bal_stdscal.csv"
full_path = os.path.join(pathds,file_name)
print(full_path)
# Out:
# /home/user/01Code/00Datasets_final/00BalancedDS/HalfCloneID20bal_stdscal.csv

# %%
df = pd.read_csv(full_path)

# %%
df.shape
# Out:
# (1342432, 67)

# %%
neurons=df.shape[1]-1
batch_size=df.shape[1]-1
print(neurons)
print(batch_size)
# Out:
# 66
# 66

# %% [markdown]
# #### 4.2 Explaining the data

# %%
#if you don't have an intuitive sense of how imbalanced these two classes are, let's go visual
count_classes = pd.value_counts(df['class'], sort = True)
print('Class 0:', count_classes[0])
print('Class 1:', count_classes[1])
print('Proportion:', round(count_classes[0] / count_classes[1], 3), ': 1')
# Out:
# Class 0: 671216
# Class 1: 671216
# Proportion: 1.0 : 1

# %%
count_classes.plot(kind = 'bar', rot=0)
plt.xticks(range(2), ['Normal [0]','Malicious [1]'])
plt.title("Frequency by observation number")
plt.xlabel("Class")
plt.ylabel("Number of Observations");

# %%
#set random seed and percentage of test data
RANDOM_SEED = 23 #used to help randomly select the data points
TEST_PCT = 0.20 # 20% of the data

# %%
train, test_df = train_test_split(df, test_size=TEST_PCT, random_state=RANDOM_SEED)

# %% [markdown]
# + df -> original dataset
# + train -> subset of 80% from original dataset
# + test_df -> subset of 20% from original dataset

# %%
train_df, dev_df = train_test_split(train, test_size=TEST_PCT, random_state=RANDOM_SEED)

# %% [markdown]
# + train -> subset of 80% from original dataset
# + train_df -> subset of 80% from train
# + dev_df -> subset of 20% from train

# %%
# Check distribution of mal samples in train and test set
print(train_df.iloc[:, batch_size].sum()/train_df.shape[0]) 
print(dev_df.iloc[:, batch_size].sum()/dev_df.shape[0]) 
print(test_df.iloc[:, batch_size].sum()/test_df.shape[0])
# Out:
# 0.5008648022012301
# 0.4985497395117999
# 0.49839284583611126

# %%
train_x = train_df.iloc[:, :batch_size] 
dev_x = dev_df.iloc[:, :batch_size] 
test_x = test_df.iloc[:, :batch_size]

# %% [markdown]
# + train_x -> features of train_df **Training subset for AE**
# + dev_x -> features of dev_df **Validation subset for AE**
# + test_x -> features of test_df **Testing subset for ANN**

# %%
# Define the final train and test sets
train_y = train_df.iloc[:,batch_size]
dev_y = dev_df.iloc[:,batch_size]
test_y = test_df.iloc[:,batch_size]

# %% [markdown]
# + train_y -> **Labels for supervised training of ANN**
# + dev_y -> labels of dev_df  *not used for AE neither ANN*
# + test_y -> labels of test_df  **Ground Truth for predictions of supervised ANN**

# %%
train_x =np.array(train_x)
dev_x =np.array(dev_x)
test_x = np.array(test_x)

train_y = np.array(train_y)
dev_y = np.array(dev_y)
test_y = np.array(test_y)

print(train_x.shape[1])
# Out:
# 66

# %% [markdown]
# ### Autoencoder Function

# %%
def ae(factor_enc_dim, enc_activation, dec_activation, 
                optimizer, loss):

    encoding_dim = int(int(train_x.shape[1])/factor_enc_dim)
    ### Define input layer
    input_data = Input(shape=(train_x.shape[1],))
    ### Define encoding layer #RELU
    encoded = Dense(encoding_dim, activation=enc_activation, name='encoded_bottle_neck')(input_data)
    ### Define decoding layer #SIMOID
    decoded = Dense(train_x.shape[1], activation=dec_activation)(encoded)
    ### Create the autoencoder model
    autoencoder = Model(input_data, decoded)
    autoencoder.compile(optimizer=optimizer,
                        loss=loss,
                        metrics=['accuracy'])
    
    print(autoencoder.summary())
    
    encoder = Model(input_data, encoded)
    encoded_train_x = encoder.predict(train_x)
    encoded_test_x = encoder.predict(test_x)
    
    return autoencoder,encoded_train_x,encoded_test_x

# %%
def spae(factor_enc_dim,dec_activation,enc_activation,
         optimizer,loss):

    encoding_dim = int(int(train_x.shape[1])/factor_enc_dim)
    ### Define input layer
    input_data = Input(shape=(train_x.shape[1],))
    ### Define encoding layer
    encoded = Dense(encoding_dim, activity_regularizer=regularizers.l1(1e-4), activation=enc_activation, name='encoded_bottle_neck')(input_data)
    ### Define decoding layer
    decoded = Dense(train_x.shape[1], activation=dec_activation)(encoded)
    ### Create the autoencoder model
    autoencoder = Model(input_data, decoded)
    autoencoder.compile(optimizer=optimizer,
                        loss=loss,
                        metrics=['accuracy'])
    
    print(autoencoder.summary())
    
    encoder = Model(input_data, encoded)
    encoded_train_x = encoder.predict(train_x)
    encoded_test_x = encoder.predict(test_x)
    
    return autoencoder,encoded_train_x,encoded_test_x

# %%
def to_pca(thr):
    #train_x_pca,test_x_pca = to_pca(0.95)
    pca = PCA(n_components = thr, svd_solver = 'full')
    train_x_ = np.array(train_x)
    print(type(train_x_))

    test_x_ = np.array(test_x)
    print(type(test_x_))
    
    start_time = time.time()
    print(time.ctime(start_time))

    train_x_pca = pca.fit_transform(train_x_)
    print(train_x_pca.shape)

    test_x_pca = pca.fit_transform(test_x_)
    print(test_x_pca.shape)

    elapsed_time = (time.time() - start_time)

    print("--- PCA spent %s seconds ---" %elapsed_time )
    
    return  train_x_pca,test_x_pca

# %%
def fit_ae(checkpoint_file, autoencoder,
           epochs, batch_size, shuffle):
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5)

    cp = ModelCheckpoint(filepath=checkpoint_file,
                                   save_best_only=True,
                                   verbose=verbose_level)

    tb = TensorBoard(log_dir='./logs',
                    histogram_freq=0,
                    write_graph=True,
                    write_images=True)

    start_time = datetime.now()
    print(datetime.ctime(start_time))

    hist_auto = autoencoder.fit(train_x, train_x,
                    epochs=epochs,
                    batch_size=batch_size,
                    shuffle=shuffle,
                    verbose=verbose_level,
                    callbacks=[early_stopping, cp, tb],
                    validation_data=(dev_x, dev_x))

    time_elapsed = datetime.now() - start_time 
    print("Time elapsed (hh:mm:ss.ms) {}".format(time_elapsed))
    
    return hist_auto

# %%
def plot_hist_auto(hist_auto, fig_file):
    best_loss_value = hist_auto.history['loss'][-1]
    print('Best loss value:', best_loss_value)

    # Summarize history for loss
    plt.figure()
    plt.plot(hist_auto.history['loss'])
    plt.plot(hist_auto.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.savefig(fig_file)
    plt.show()
    
    return best_loss_value

# %%
def ann_2h(neurons,encoded_train_x,init_mode,activation_input,
               weight_constraint,dropout_rate,activation_output,
               loss,optimizer):

    # create model
    model = Sequential()

    model.add(Dense(neurons, input_dim=encoded_train_x.shape[1],
                    kernel_initializer=init_mode,
                    #kernel_regularizer=regularizers.l2(0.02), #from example
                    activation=activation_input,
                    kernel_constraint=maxnorm(weight_constraint)
                    )
              )

#     #Hidden Layer
    model.add(Dense(int(neurons-int(neurons/4)), activation="relu", kernel_initializer=init_mode)) #rezvy

    model.add(Dense(int(neurons-int((neurons/4)*2)), activation="relu", kernel_initializer=init_mode)) #rezvy
    model.add(BatchNormalization()) #commented for ex
    model.add(Dropout(dropout_rate))
    
    model.add(Dense(1, activation=activation_output)) #example
    
    # Compile model
    model.compile(loss=loss, 
                  optimizer=optimizer, 
                  metrics=['accuracy'])
    
    print(model.summary())
    
    return model

# %%
def ann_2h_():

    # create model
    model = Sequential()

    model.add(Dense(neurons, input_dim=input_dim,
                    kernel_initializer=init_mode,
                    #kernel_regularizer=regularizers.l2(0.02), #from example
                    activation=activation_input,
                    kernel_constraint=maxnorm(weight_constraint)
                    )
              )

#     #Hidden Layer
    model.add(Dense(int(neurons-int(neurons/4)), activation="relu", kernel_initializer=init_mode)) #rezvy

    model.add(Dense(int(neurons-int((neurons/4)*2)), activation="relu", kernel_initializer=init_mode)) #rezvy
    model.add(BatchNormalization()) #commented for ex
    model.add(Dropout(dropout_rate))
    
    model.add(Dense(1, activation=activation_output)) #example
    
    # Compile model
    model.compile(loss=loss, 
                  optimizer=optimizer, 
                  metrics=['accuracy'])
    
    print(model.summary())
    
    return model

# %%
def ann_fit(checkpoint_file,ann,enc_train_x,train_y,epochs,shuffle,batch_size):
    early_stopping = EarlyStopping(monitor='val_loss', patience=5)

    cp = ModelCheckpoint(filepath=checkpoint_file,
                                   save_best_only=True,
                                   verbose=verbose_level)

    tb = TensorBoard(log_dir='./logs',
                    histogram_freq=0,
                    write_graph=True,
                    write_images=True)

    start_time = datetime.now()
    print(datetime.ctime(start_time))

    history = ann.fit(enc_train_x,
                      train_y,
                      validation_split=0.2,
                      callbacks=[early_stopping, cp, tb],
                      epochs=epochs,
                      shuffle=shuffle,
                      batch_size=batch_size,
                      verbose=verbose_level)

    time_elapsed = datetime.now() - start_time 
    print("Time elapsed (hh:mm:ss.ms) {}".format(time_elapsed))

    return history

# %%
def ann_predict(ann,enc_test_x):
    pred_ann_prob = ann.predict(enc_test_x)
    pred_ann_prob.shape
    pred_ann_prob = pred_ann_prob[:,0]
    pred_ann_01 = np.where(pred_ann_prob > 0.5, 1, 0)
    
    #Print accuracy
    acc_ann = accuracy_score(test_y, pred_ann_01)
    print('Overall accuracy of Neural Network model:', acc_ann)

    classiBM = "NN"
    preBM = (sm.precision_score(test_y, pred_ann_01)*100) 
    recallBM = (sm.recall_score(test_y, pred_ann_01)*100) 
    f1scoreBM = (sm.f1_score(test_y, pred_ann_01)*100)
    print(sm.classification_report(test_y, pred_ann_01,digits=4))
    
    return pred_ann_prob, pred_ann_01

# %%
def ann_predict_():
    early_stopping = EarlyStopping(monitor='loss', patience=10)

    start_time = datetime.now()
    print(datetime.ctime(start_time))  

    modelk = KerasClassifier(build_fn=ann_2h_,
                             epochs=epochs, 
                             batch_size=batch_size, 
                             verbose=verbose_level
                            )

    pred_ann_prob = cross_val_predict(modelk,
                                      enc_test_x,
                                      test_y,
                                      cv=KFold(n_splits=5, random_state=23),
                                      verbose=1)

    time_elapsed = datetime.now() - start_time 
    print("Time elapsed (hh:mm:ss.ms) {}".format(time_elapsed))

    pred_ann_prob.shape
    pred_ann_prob = pred_ann_prob[:,0]
    pred_ann_01 = np.where(pred_ann_prob > 0.5, 1, 0)

    #Print accuracy
    acc_ann = accuracy_score(test_y, pred_ann_01)
    print('Overall accuracy of Neural Network model:', acc_ann)

    classiBM = "NN"
    preBM = (sm.precision_score(test_y, pred_ann_01)*100) 
    recallBM = (sm.recall_score(test_y, pred_ann_01)*100) 
    f1scoreBM = (sm.f1_score(test_y, pred_ann_01)*100)
    print(sm.classification_report(test_y, pred_ann_01,digits=4))
    
    return pred_ann_prob,pred_ann_01

# %%
def plot_roc_cm(pred_ann_prob, pred_ann_01, roc_file, cm_file):
    false_positive_rate, recall, thresholds = roc_curve(test_y, pred_ann_prob)
    roc_auc = auc(false_positive_rate, recall)
    plt.figure()
    plt.title('Receiver Operating Characteristic (ROC)')
    plt.plot(false_positive_rate, recall, 'b', label = 'AUC = %0.3f' %roc_auc)
    plt.legend(loc='lower right')
    plt.plot([0,1], [0,1], 'r--')
    plt.xlim([0.0,1.0])
    plt.ylim([0.0,1.0])
    plt.ylabel('Recall')
    plt.xlabel('Fall-out (1-Specificity)')
    plt.savefig(roc_file)
    plt.show()
    
    cm = confusion_matrix(test_y, pred_ann_01)
    labels = ['Normal', 'Malicious']
    plt.figure(figsize=(8,6))
    sns.heatmap(cm,xticklabels=labels, yticklabels=labels, annot=True, fmt='d', cmap="RdYlGn", vmin = 0.2);
    plt.title('Confusion Matrix')
    plt.ylabel('True Class')
    plt.xlabel('Predicted Class')
    plt.savefig(cm_file)
    plt.show()

# %% [markdown]
# ### **---------- PCA Dimensionality reduction ----------**

# %%
train_x_pca,test_x_pca = to_pca(0.95)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Mon Jul 15 13:00:22 2019
# (859156, 18)
# (268487, 18)
# --- PCA spent 7.840341567993164 seconds ---

# %% [markdown]
# ### **---------- AE Dimensionality reduction ----------**

# %%
ae_sigmoid_adam_mse,enc_train_x_asam,enc_test_x_asam = ae(factor_enc_dim = 1.5,
                                                          enc_activation = 'relu',
                                                          dec_activation = 'sigmoid',
                                                          optimizer='Adam',
                                                          loss='mean_squared_error')
# Out:
# WARNING:tensorflow:From /home/user/anaconda3/envs/deepl/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 66)                0
# _________________________________________________________________
# encoded_bottle_neck (Dense)  (None, 44)                2948
# _________________________________________________________________
# dense_1 (Dense)              (None, 66)                2970
# =================================================================
# Total params: 5,918
# Trainable params: 5,918
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#ae_sigmoid_adam_mse = load_model('ae_sigmoid_adam_mse_redds10bal.h5')

# %%
hist_ae_sigmoid_adam_mse = fit_ae(checkpoint_file = "./H5files/ae_sigmoid_adam_mse_redds"+str(dsnum)+"bal.h5",
                                  autoencoder = ae_sigmoid_adam_mse, 
                                  epochs = 200, 
                                  batch_size = batch_size,
                                  shuffle = False)
# Out:
# Mon Jul 15 13:00:42 2019
# WARNING:tensorflow:From /home/user/anaconda3/envs/deepl/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 859156 samples, validate on 214789 samples
# Epoch 1/200
# 859156/859156 [==============================] - 23s 26us/step - loss: 0.1617 - acc: 0.1883 - val_loss: 0.1556 - val_acc: 0.1870
#
# Epoch 00001: val_loss improved from inf to 0.15563, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 2/200
# 859156/859156 [==============================] - 23s 26us/step - loss: 0.1573 - acc: 0.1716 - val_loss: 0.1556 - val_acc: 0.1544
#
# Epoch 00002: val_loss improved from 0.15563 to 0.15561, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 3/200
# 859156/859156 [==============================] - 23s 26us/step - loss: 0.1573 - acc: 0.1382 - val_loss: 0.1556 - val_acc: 0.1408
#
# Epoch 00003: val_loss improved from 0.15561 to 0.15561, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 4/200
# 859156/859156 [==============================] - 22s 26us/step - loss: 0.1573 - acc: 0.1648 - val_loss: 0.1556 - val_acc: 0.1657
#
# Epoch 00004: val_loss improved from 0.15561 to 0.15560, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 5/200
# 859156/859156 [==============================] - 22s 26us/step - loss: 0.1573 - acc: 0.1727 - val_loss: 0.1556 - val_acc: 0.1781
#
# Epoch 00005: val_loss improved from 0.15560 to 0.15560, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 6/200
# 859156/859156 [==============================] - 22s 26us/step - loss: 0.1573 - acc: 0.1734 - val_loss: 0.1556 - val_acc: 0.1796
#
# Epoch 00006: val_loss improved from 0.15560 to 0.15560, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 7/200
# 859156/859156 [==============================] - 22s 26us/step - loss: 0.1573 - acc: 0.1719 - val_loss: 0.1556 - val_acc: 0.1801
#
# Epoch 00007: val_loss improved from 0.15560 to 0.15560, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 8/200
# 859156/859156 [==============================] - 22s 26us/step - loss: 0.1573 - acc: 0.1791 - val_loss: 0.1556 - val_acc: 0.1788
#
# Epoch 00008: val_loss improved from 0.15560 to 0.15560, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 9/200
# 859156/859156 [==============================] - 22s 26us/step - loss: 0.1573 - acc: 0.1765 - val_loss: 0.1556 - val_acc: 0.1797
#
# Epoch 00009: val_loss improved from 0.15560 to 0.15560, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 10/200
# 859156/859156 [==============================] - 22s 25us/step - loss: 0.1573 - acc: 0.1766 - val_loss: 0.1556 - val_acc: 0.1691
#
# Epoch 00010: val_loss improved from 0.15560 to 0.15560, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 11/200
# 859156/859156 [==============================] - 22s 25us/step - loss: 0.1573 - acc: 0.1894 - val_loss: 0.1556 - val_acc: 0.1741
#
# Epoch 00011: val_loss improved from 0.15560 to 0.15560, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 12/200
# 859156/859156 [==============================] - 22s 25us/step - loss: 0.1573 - acc: 0.1706 - val_loss: 0.1556 - val_acc: 0.1638
#
# Epoch 00012: val_loss improved from 0.15560 to 0.15560, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 13/200
# 859156/859156 [==============================] - 22s 25us/step - loss: 0.1573 - acc: 0.1556 - val_loss: 0.1556 - val_acc: 0.1479
#
# Epoch 00013: val_loss improved from 0.15560 to 0.15560, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 14/200
# 859156/859156 [==============================] - 22s 25us/step - loss: 0.1573 - acc: 0.1491 - val_loss: 0.1556 - val_acc: 0.1500
#
# Epoch 00014: val_loss improved from 0.15560 to 0.15560, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 15/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1573 - acc: 0.1394 - val_loss: 0.1556 - val_acc: 0.1337
#
# Epoch 00015: val_loss improved from 0.15560 to 0.15558, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 16/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1573 - acc: 0.1346 - val_loss: 0.1556 - val_acc: 0.1398
#
# Epoch 00016: val_loss improved from 0.15558 to 0.15558, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 17/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1573 - acc: 0.1405 - val_loss: 0.1556 - val_acc: 0.1143
#
# Epoch 00017: val_loss improved from 0.15558 to 0.15558, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 18/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1573 - acc: 0.1460 - val_loss: 0.1556 - val_acc: 0.1555
#
# Epoch 00018: val_loss improved from 0.15558 to 0.15558, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 19/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1573 - acc: 0.1547 - val_loss: 0.1556 - val_acc: 0.1509
#
# Epoch 00019: val_loss improved from 0.15558 to 0.15558, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 20/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1573 - acc: 0.1618 - val_loss: 0.1556 - val_acc: 0.1647
#
# Epoch 00020: val_loss improved from 0.15558 to 0.15558, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 21/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1573 - acc: 0.1581 - val_loss: 0.1556 - val_acc: 0.1594
#
# Epoch 00021: val_loss improved from 0.15558 to 0.15558, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 22/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1573 - acc: 0.1578 - val_loss: 0.1556 - val_acc: 0.1611
#
# Epoch 00022: val_loss improved from 0.15558 to 0.15558, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 23/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1573 - acc: 0.1708 - val_loss: 0.1556 - val_acc: 0.1630
#
# Epoch 00023: val_loss improved from 0.15558 to 0.15558, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 24/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1573 - acc: 0.1602 - val_loss: 0.1556 - val_acc: 0.1688
#
# Epoch 00024: val_loss improved from 0.15558 to 0.15558, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 25/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1573 - acc: 0.1719 - val_loss: 0.1556 - val_acc: 0.1689
#
# Epoch 00025: val_loss improved from 0.15558 to 0.15558, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 26/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1573 - acc: 0.1604 - val_loss: 0.1556 - val_acc: 0.1502
#
# Epoch 00026: val_loss improved from 0.15558 to 0.15558, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 27/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1573 - acc: 0.1522 - val_loss: 0.1556 - val_acc: 0.1535
#
# Epoch 00027: val_loss improved from 0.15558 to 0.15558, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 28/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1573 - acc: 0.1580 - val_loss: 0.1556 - val_acc: 0.1625
#
# Epoch 00028: val_loss improved from 0.15558 to 0.15558, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 29/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1573 - acc: 0.1575 - val_loss: 0.1556 - val_acc: 0.1621
#
# Epoch 00029: val_loss did not improve from 0.15558
# Epoch 30/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1573 - acc: 0.1630 - val_loss: 0.1556 - val_acc: 0.1792
#
# Epoch 00030: val_loss improved from 0.15558 to 0.15558, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 31/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1573 - acc: 0.1658 - val_loss: 0.1556 - val_acc: 0.1531
#
# Epoch 00031: val_loss improved from 0.15558 to 0.15558, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 32/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1573 - acc: 0.1817 - val_loss: 0.1556 - val_acc: 0.1939
#
# Epoch 00032: val_loss improved from 0.15558 to 0.15558, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 33/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1573 - acc: 0.2041 - val_loss: 0.1556 - val_acc: 0.2099
#
# Epoch 00033: val_loss improved from 0.15558 to 0.15558, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 34/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1573 - acc: 0.2185 - val_loss: 0.1556 - val_acc: 0.2144
#
# Epoch 00034: val_loss improved from 0.15558 to 0.15557, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 35/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1573 - acc: 0.1986 - val_loss: 0.1556 - val_acc: 0.1927
#
# Epoch 00035: val_loss improved from 0.15557 to 0.15557, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 36/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1573 - acc: 0.1908 - val_loss: 0.1556 - val_acc: 0.1997
#
# Epoch 00036: val_loss improved from 0.15557 to 0.15557, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 37/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1573 - acc: 0.2005 - val_loss: 0.1556 - val_acc: 0.2070
#
# Epoch 00037: val_loss improved from 0.15557 to 0.15557, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 38/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1573 - acc: 0.1972 - val_loss: 0.1556 - val_acc: 0.2001
#
# Epoch 00038: val_loss improved from 0.15557 to 0.15557, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 39/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1573 - acc: 0.1956 - val_loss: 0.1556 - val_acc: 0.1867
#
# Epoch 00039: val_loss improved from 0.15557 to 0.15557, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 40/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1573 - acc: 0.1869 - val_loss: 0.1556 - val_acc: 0.1931
#
# Epoch 00040: val_loss improved from 0.15557 to 0.15557, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 41/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1573 - acc: 0.1936 - val_loss: 0.1556 - val_acc: 0.1959
#
# Epoch 00041: val_loss did not improve from 0.15557
# Epoch 42/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1573 - acc: 0.1848 - val_loss: 0.1556 - val_acc: 0.1707
#
# Epoch 00042: val_loss improved from 0.15557 to 0.15557, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 43/200
# 859156/859156 [==============================] - 20s 23us/step - loss: 0.1573 - acc: 0.1859 - val_loss: 0.1556 - val_acc: 0.1917
#
# Epoch 00043: val_loss improved from 0.15557 to 0.15557, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 44/200
# 859156/859156 [==============================] - 22s 25us/step - loss: 0.1573 - acc: 0.1892 - val_loss: 0.1556 - val_acc: 0.1932
#
# Epoch 00044: val_loss did not improve from 0.15557
# Epoch 45/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1573 - acc: 0.1841 - val_loss: 0.1556 - val_acc: 0.1832
#
# Epoch 00045: val_loss improved from 0.15557 to 0.15557, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 46/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1573 - acc: 0.1729 - val_loss: 0.1556 - val_acc: 0.1687
#
# Epoch 00046: val_loss improved from 0.15557 to 0.15557, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 47/200
# 859156/859156 [==============================] - 22s 25us/step - loss: 0.1573 - acc: 0.1685 - val_loss: 0.1556 - val_acc: 0.1711
#
# Epoch 00047: val_loss did not improve from 0.15557
# Epoch 48/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1573 - acc: 0.1754 - val_loss: 0.1556 - val_acc: 0.1856
#
# Epoch 00048: val_loss improved from 0.15557 to 0.15557, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 49/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1573 - acc: 0.1782 - val_loss: 0.1556 - val_acc: 0.1882
#
# Epoch 00049: val_loss improved from 0.15557 to 0.15557, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 50/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1573 - acc: 0.1787 - val_loss: 0.1556 - val_acc: 0.1828
#
# Epoch 00050: val_loss did not improve from 0.15557
# Epoch 51/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1573 - acc: 0.1749 - val_loss: 0.1556 - val_acc: 0.1657
#
# Epoch 00051: val_loss improved from 0.15557 to 0.15557, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 52/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1573 - acc: 0.1712 - val_loss: 0.1556 - val_acc: 0.1772
#
# Epoch 00052: val_loss improved from 0.15557 to 0.15557, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 53/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.1662 - val_loss: 0.1556 - val_acc: 0.1708
#
# Epoch 00053: val_loss improved from 0.15557 to 0.15557, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 54/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.1602 - val_loss: 0.1556 - val_acc: 0.1557
#
# Epoch 00054: val_loss improved from 0.15557 to 0.15557, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 55/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.1476 - val_loss: 0.1556 - val_acc: 0.1520
#
# Epoch 00055: val_loss improved from 0.15557 to 0.15557, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 56/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.1501 - val_loss: 0.1556 - val_acc: 0.1566
#
# Epoch 00056: val_loss improved from 0.15557 to 0.15557, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 57/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1572 - acc: 0.1599 - val_loss: 0.1556 - val_acc: 0.1622
#
# Epoch 00057: val_loss improved from 0.15557 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 58/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.1580 - val_loss: 0.1556 - val_acc: 0.1580
#
# Epoch 00058: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 59/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.1756 - val_loss: 0.1556 - val_acc: 0.1974
#
# Epoch 00059: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 60/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.1942 - val_loss: 0.1556 - val_acc: 0.1943
#
# Epoch 00060: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 61/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.1839 - val_loss: 0.1556 - val_acc: 0.1776
#
# Epoch 00061: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 62/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.1657 - val_loss: 0.1556 - val_acc: 0.1646
#
# Epoch 00062: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 63/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.1633 - val_loss: 0.1556 - val_acc: 0.1629
#
# Epoch 00063: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 64/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.1602 - val_loss: 0.1556 - val_acc: 0.1625
#
# Epoch 00064: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 65/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1572 - acc: 0.1623 - val_loss: 0.1556 - val_acc: 0.1618
#
# Epoch 00065: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 66/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.1632 - val_loss: 0.1556 - val_acc: 0.1710
#
# Epoch 00066: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 67/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.1707 - val_loss: 0.1556 - val_acc: 0.1679
#
# Epoch 00067: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 68/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.1711 - val_loss: 0.1556 - val_acc: 0.1791
#
# Epoch 00068: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 69/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.1774 - val_loss: 0.1556 - val_acc: 0.1987
#
# Epoch 00069: val_loss did not improve from 0.15556
# Epoch 70/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.1908 - val_loss: 0.1556 - val_acc: 0.1921
#
# Epoch 00070: val_loss did not improve from 0.15556
# Epoch 71/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.1959 - val_loss: 0.1556 - val_acc: 0.2094
#
# Epoch 00071: val_loss did not improve from 0.15556
# Epoch 72/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2014 - val_loss: 0.1556 - val_acc: 0.2004
#
# Epoch 00072: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 73/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2025 - val_loss: 0.1556 - val_acc: 0.2241
#
# Epoch 00073: val_loss did not improve from 0.15556
# Epoch 74/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2151 - val_loss: 0.1556 - val_acc: 0.2014
#
# Epoch 00074: val_loss did not improve from 0.15556
# Epoch 75/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.1987 - val_loss: 0.1556 - val_acc: 0.1979
#
# Epoch 00075: val_loss did not improve from 0.15556
# Epoch 76/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2054 - val_loss: 0.1556 - val_acc: 0.1508
#
# Epoch 00076: val_loss did not improve from 0.15556
# Epoch 77/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2084 - val_loss: 0.1556 - val_acc: 0.1782
#
# Epoch 00077: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 78/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2106 - val_loss: 0.1556 - val_acc: 0.2370
#
# Epoch 00078: val_loss did not improve from 0.15556
# Epoch 79/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2206 - val_loss: 0.1556 - val_acc: 0.2151
#
# Epoch 00079: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 80/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2079 - val_loss: 0.1556 - val_acc: 0.1847
#
# Epoch 00080: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 81/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.1950 - val_loss: 0.1556 - val_acc: 0.1990
#
# Epoch 00081: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 82/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.1999 - val_loss: 0.1556 - val_acc: 0.2110
#
# Epoch 00082: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 83/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2076 - val_loss: 0.1556 - val_acc: 0.2076
#
# Epoch 00083: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 84/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2086 - val_loss: 0.1556 - val_acc: 0.2174
#
# Epoch 00084: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 85/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1572 - acc: 0.2136 - val_loss: 0.1556 - val_acc: 0.2181
#
# Epoch 00085: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 86/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1572 - acc: 0.2109 - val_loss: 0.1556 - val_acc: 0.2028
#
# Epoch 00086: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 87/200
# 859156/859156 [==============================] - 20s 23us/step - loss: 0.1572 - acc: 0.2109 - val_loss: 0.1556 - val_acc: 0.2157
#
# Epoch 00087: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 88/200
# 859156/859156 [==============================] - 20s 23us/step - loss: 0.1572 - acc: 0.2111 - val_loss: 0.1556 - val_acc: 0.2128
#
# Epoch 00088: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 89/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2062 - val_loss: 0.1556 - val_acc: 0.2053
#
# Epoch 00089: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 90/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2062 - val_loss: 0.1556 - val_acc: 0.2153
#
# Epoch 00090: val_loss did not improve from 0.15556
# Epoch 91/200
# 859156/859156 [==============================] - 21s 24us/step - loss: 0.1572 - acc: 0.2147 - val_loss: 0.1556 - val_acc: 0.2320
#
# Epoch 00091: val_loss did not improve from 0.15556
# Epoch 92/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2231 - val_loss: 0.1556 - val_acc: 0.2263
#
# Epoch 00092: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 93/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2244 - val_loss: 0.1556 - val_acc: 0.2314
#
# Epoch 00093: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 94/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2238 - val_loss: 0.1556 - val_acc: 0.2129
#
# Epoch 00094: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 95/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2226 - val_loss: 0.1556 - val_acc: 0.2283
#
# Epoch 00095: val_loss did not improve from 0.15556
# Epoch 96/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2178 - val_loss: 0.1556 - val_acc: 0.2208
#
# Epoch 00096: val_loss improved from 0.15556 to 0.15556, saving model to ./H5files/ae_sigmoid_adam_mse_redds20bal.h5
# Epoch 97/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2198 - val_loss: 0.1556 - val_acc: 0.2207
#
# Epoch 00097: val_loss did not improve from 0.15556
# Epoch 98/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2192 - val_loss: 0.1556 - val_acc: 0.2291
#
# Epoch 00098: val_loss did not improve from 0.15556
# Epoch 99/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2286 - val_loss: 0.1556 - val_acc: 0.2262
#
# Epoch 00099: val_loss did not improve from 0.15556
# Epoch 100/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2115 - val_loss: 0.1556 - val_acc: 0.2020
#
# Epoch 00100: val_loss did not improve from 0.15556
# Epoch 101/200
# 859156/859156 [==============================] - 20s 24us/step - loss: 0.1572 - acc: 0.2124 - val_loss: 0.1556 - val_acc: 0.2227
#
# Epoch 00101: val_loss did not improve from 0.15556
# Time elapsed (hh:mm:ss.ms) 0:34:57.436581

# %%
best_loss_value_ae_sigmoid_adam_mse  = plot_hist_auto(hist_ae_sigmoid_adam_mse, './Figures/hist_ae_sigmoid_adam_mse.png')
# Out:
# Best loss value: 0.15723565515987012

# %% [markdown]
# ### **---------- SPAE Dimensionality reduction ----------**

# %%
spae_sigmoid_adam_mse,enc_train_x_spsam,enc_test_x_spsam = spae(factor_enc_dim = 1.5,
                                                          enc_activation = 'relu',
                                                          dec_activation = 'sigmoid',
                                                          optimizer='Adam',
                                                          loss='mean_squared_error')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 66)                0
# _________________________________________________________________
# encoded_bottle_neck (Dense)  (None, 44)                2948
# _________________________________________________________________
# dense_2 (Dense)              (None, 66)                2970
# =================================================================
# Total params: 5,918
# Trainable params: 5,918
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#spae_sigmoid_adam_mse = load_model('spae_sigmoid_adam_mse_redds20bal.h5')

# %%
hist_spae_sigmoid_adam_mse = fit_ae(checkpoint_file = "./H5files/spae_sigmoid_adam_mse_redds"+str(dsnum)+"bal.h5",
                                  autoencoder = spae_sigmoid_adam_mse, 
                                  epochs = 200, 
                                  batch_size = batch_size,
                                  shuffle = False)
# Out:
# Mon Jul 15 13:35:50 2019
# Train on 859156 samples, validate on 214789 samples
# Epoch 1/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.2100 - acc: 0.1445 - val_loss: 0.1868 - val_acc: 0.1423
#
# Epoch 00001: val_loss improved from inf to 0.18684, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 2/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1832 - acc: 0.1289 - val_loss: 0.1774 - val_acc: 0.1356
#
# Epoch 00002: val_loss improved from 0.18684 to 0.17737, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 3/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1766 - acc: 0.1496 - val_loss: 0.1730 - val_acc: 0.1559
#
# Epoch 00003: val_loss improved from 0.17737 to 0.17301, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 4/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1735 - acc: 0.1715 - val_loss: 0.1706 - val_acc: 0.1873
#
# Epoch 00004: val_loss improved from 0.17301 to 0.17063, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 5/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1715 - acc: 0.2013 - val_loss: 0.1691 - val_acc: 0.2282
#
# Epoch 00005: val_loss improved from 0.17063 to 0.16905, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 6/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1702 - acc: 0.2279 - val_loss: 0.1679 - val_acc: 0.2371
#
# Epoch 00006: val_loss improved from 0.16905 to 0.16788, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 7/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1691 - acc: 0.2425 - val_loss: 0.1669 - val_acc: 0.2537
#
# Epoch 00007: val_loss improved from 0.16788 to 0.16689, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 8/200
# 859156/859156 [==============================] - 22s 26us/step - loss: 0.1682 - acc: 0.2607 - val_loss: 0.1662 - val_acc: 0.2677
#
# Epoch 00008: val_loss improved from 0.16689 to 0.16616, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 9/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1676 - acc: 0.2674 - val_loss: 0.1656 - val_acc: 0.2731
#
# Epoch 00009: val_loss improved from 0.16616 to 0.16560, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 10/200
# 859156/859156 [==============================] - 22s 25us/step - loss: 0.1671 - acc: 0.2716 - val_loss: 0.1652 - val_acc: 0.2769
#
# Epoch 00010: val_loss improved from 0.16560 to 0.16515, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 11/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1667 - acc: 0.2747 - val_loss: 0.1647 - val_acc: 0.2812
#
# Epoch 00011: val_loss improved from 0.16515 to 0.16467, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 12/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1663 - acc: 0.2763 - val_loss: 0.1644 - val_acc: 0.2588
#
# Epoch 00012: val_loss improved from 0.16467 to 0.16439, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 13/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1660 - acc: 0.2746 - val_loss: 0.1640 - val_acc: 0.2709
#
# Epoch 00013: val_loss improved from 0.16439 to 0.16403, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 14/200
# 859156/859156 [==============================] - 22s 26us/step - loss: 0.1657 - acc: 0.2718 - val_loss: 0.1638 - val_acc: 0.2801
#
# Epoch 00014: val_loss improved from 0.16403 to 0.16379, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 15/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1654 - acc: 0.2725 - val_loss: 0.1634 - val_acc: 0.2862
#
# Epoch 00015: val_loss improved from 0.16379 to 0.16344, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 16/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1653 - acc: 0.2670 - val_loss: 0.1634 - val_acc: 0.2780
#
# Epoch 00016: val_loss improved from 0.16344 to 0.16335, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 17/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1650 - acc: 0.2678 - val_loss: 0.1631 - val_acc: 0.2771
#
# Epoch 00017: val_loss improved from 0.16335 to 0.16315, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 18/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1648 - acc: 0.2692 - val_loss: 0.1630 - val_acc: 0.2935
#
# Epoch 00018: val_loss improved from 0.16315 to 0.16299, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 19/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1647 - acc: 0.2781 - val_loss: 0.1629 - val_acc: 0.2830
#
# Epoch 00019: val_loss improved from 0.16299 to 0.16287, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 20/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1645 - acc: 0.2755 - val_loss: 0.1627 - val_acc: 0.2748
#
# Epoch 00020: val_loss improved from 0.16287 to 0.16275, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 21/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1644 - acc: 0.2769 - val_loss: 0.1627 - val_acc: 0.2929
#
# Epoch 00021: val_loss improved from 0.16275 to 0.16270, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 22/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1642 - acc: 0.2808 - val_loss: 0.1625 - val_acc: 0.2839
#
# Epoch 00022: val_loss improved from 0.16270 to 0.16245, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 23/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1641 - acc: 0.2837 - val_loss: 0.1624 - val_acc: 0.2890
#
# Epoch 00023: val_loss improved from 0.16245 to 0.16240, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 24/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1641 - acc: 0.2814 - val_loss: 0.1623 - val_acc: 0.1828
#
# Epoch 00024: val_loss improved from 0.16240 to 0.16228, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 25/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1640 - acc: 0.2799 - val_loss: 0.1624 - val_acc: 0.2778
#
# Epoch 00025: val_loss did not improve from 0.16228
# Epoch 26/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1639 - acc: 0.2851 - val_loss: 0.1619 - val_acc: 0.2843
#
# Epoch 00026: val_loss improved from 0.16228 to 0.16189, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 27/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1637 - acc: 0.2861 - val_loss: 0.1618 - val_acc: 0.2699
#
# Epoch 00027: val_loss improved from 0.16189 to 0.16183, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 28/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1637 - acc: 0.2876 - val_loss: 0.1618 - val_acc: 0.3055
#
# Epoch 00028: val_loss improved from 0.16183 to 0.16180, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 29/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1636 - acc: 0.2876 - val_loss: 0.1617 - val_acc: 0.2841
#
# Epoch 00029: val_loss improved from 0.16180 to 0.16171, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 30/200
# 859156/859156 [==============================] - 22s 25us/step - loss: 0.1635 - acc: 0.2896 - val_loss: 0.1617 - val_acc: 0.2805
#
# Epoch 00030: val_loss improved from 0.16171 to 0.16169, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 31/200
# 859156/859156 [==============================] - 22s 26us/step - loss: 0.1635 - acc: 0.2750 - val_loss: 0.1617 - val_acc: 0.2620
#
# Epoch 00031: val_loss improved from 0.16169 to 0.16166, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 32/200
# 859156/859156 [==============================] - 22s 26us/step - loss: 0.1635 - acc: 0.2663 - val_loss: 0.1617 - val_acc: 0.2466
#
# Epoch 00032: val_loss did not improve from 0.16166
# Epoch 33/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1636 - acc: 0.2650 - val_loss: 0.1619 - val_acc: 0.3183
#
# Epoch 00033: val_loss did not improve from 0.16166
# Epoch 34/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1636 - acc: 0.2630 - val_loss: 0.1616 - val_acc: 0.2541
#
# Epoch 00034: val_loss improved from 0.16166 to 0.16159, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 35/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1635 - acc: 0.2652 - val_loss: 0.1617 - val_acc: 0.2627
#
# Epoch 00035: val_loss did not improve from 0.16159
# Epoch 36/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1635 - acc: 0.2676 - val_loss: 0.1616 - val_acc: 0.2577
#
# Epoch 00036: val_loss improved from 0.16159 to 0.16157, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 37/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1634 - acc: 0.2665 - val_loss: 0.1616 - val_acc: 0.2603
#
# Epoch 00037: val_loss did not improve from 0.16157
# Epoch 38/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1634 - acc: 0.2652 - val_loss: 0.1619 - val_acc: 0.2768
#
# Epoch 00038: val_loss did not improve from 0.16157
# Epoch 39/200
# 859156/859156 [==============================] - 22s 25us/step - loss: 0.1633 - acc: 0.2676 - val_loss: 0.1616 - val_acc: 0.2815
#
# Epoch 00039: val_loss did not improve from 0.16157
# Epoch 40/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1633 - acc: 0.2672 - val_loss: 0.1615 - val_acc: 0.2609
#
# Epoch 00040: val_loss improved from 0.16157 to 0.16148, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 41/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1633 - acc: 0.2725 - val_loss: 0.1617 - val_acc: 0.3304
#
# Epoch 00041: val_loss did not improve from 0.16148
# Epoch 42/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1632 - acc: 0.2676 - val_loss: 0.1619 - val_acc: 0.2393
#
# Epoch 00042: val_loss did not improve from 0.16148
# Epoch 43/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1632 - acc: 0.2706 - val_loss: 0.1616 - val_acc: 0.2650
#
# Epoch 00043: val_loss did not improve from 0.16148
# Epoch 44/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1633 - acc: 0.2689 - val_loss: 0.1616 - val_acc: 0.2576
#
# Epoch 00044: val_loss did not improve from 0.16148
# Epoch 45/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1634 - acc: 0.2769 - val_loss: 0.1613 - val_acc: 0.2861
#
# Epoch 00045: val_loss improved from 0.16148 to 0.16127, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 46/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1632 - acc: 0.2712 - val_loss: 0.1614 - val_acc: 0.2346
#
# Epoch 00046: val_loss did not improve from 0.16127
# Epoch 47/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1631 - acc: 0.2697 - val_loss: 0.1614 - val_acc: 0.2680
#
# Epoch 00047: val_loss did not improve from 0.16127
# Epoch 48/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1632 - acc: 0.2741 - val_loss: 0.1616 - val_acc: 0.3419
#
# Epoch 00048: val_loss did not improve from 0.16127
# Epoch 49/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1631 - acc: 0.2768 - val_loss: 0.1611 - val_acc: 0.2603
#
# Epoch 00049: val_loss improved from 0.16127 to 0.16114, saving model to ./H5files/spae_sigmoid_adam_mse_redds20bal.h5
# Epoch 50/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1631 - acc: 0.2783 - val_loss: 0.1617 - val_acc: 0.2232
#
# Epoch 00050: val_loss did not improve from 0.16114
# Epoch 51/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1630 - acc: 0.2711 - val_loss: 0.1617 - val_acc: 0.2886
#
# Epoch 00051: val_loss did not improve from 0.16114
# Epoch 52/200
# 859156/859156 [==============================] - 21s 25us/step - loss: 0.1630 - acc: 0.2787 - val_loss: 0.1612 - val_acc: 0.2628
#
# Epoch 00052: val_loss did not improve from 0.16114
# Epoch 53/200
# 859156/859156 [==============================] - 22s 25us/step - loss: 0.1630 - acc: 0.2814 - val_loss: 0.1613 - val_acc: 0.2613
#
# Epoch 00053: val_loss did not improve from 0.16114
# Epoch 54/200
# 859156/859156 [==============================] - 22s 26us/step - loss: 0.1630 - acc: 0.2822 - val_loss: 0.1631 - val_acc: 0.2081
#
# Epoch 00054: val_loss did not improve from 0.16114
# Time elapsed (hh:mm:ss.ms) 0:19:14.997292

# %%
best_loss_value_spae_sigmoid_adam_mse  = plot_hist_auto(hist_spae_sigmoid_adam_mse, './Figures/hist_spae_sigmoid_adam_mse.png')
# Out:
# Best loss value: 0.16301009930005536

# %%
loss_valueDict = {
    'loss_value_ae_sigmoid_adam_mse': best_loss_value_ae_sigmoid_adam_mse,
    'loss_value_spae_sigmoid_adam_mse': best_loss_value_spae_sigmoid_adam_mse
    }

# %%
loss_valueDict
# Out:
# {'loss_value_ae_sigmoid_adam_mse': 0.15723565515987012,
#  'loss_value_spae_sigmoid_adam_mse': 0.16301009930005536}

# %%
print(enc_train_x_asam.shape)
print(enc_test_x_asam.shape)

print(enc_train_x_spsam.shape)
print(enc_test_x_spsam.shape)
# Out:
# (859156, 44)
# (268487, 44)
# (859156, 44)
# (268487, 44)

# %% [markdown]
# ### **---------- RF with ae encoded DS ----------**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
pca_ = PCA(n_components = 0.95, svd_solver = 'full').fit(train_x)

plt.figure(figsize=(8,5))
n_coml = [pca_.n_components_]

plt.plot(np.cumsum(pca_.explained_variance_ratio_))
plt.xlabel('Number of Components', fontsize=14)
plt.ylabel('Variance (%)', fontsize=14) #for each component
plt.title('Pulsar Dataset Explained Variance '+str(dsnum)+' node DS', fontsize=14)

n_coml = [*n_coml]

for i, v in enumerate(n_coml):
    plt.text(v-0.8, i+0.94, '{:.0f}'.format(v), color='navy', fontsize=14)

plt.savefig('./Figures/PCA_components_ds'+str(dsnum)+'bal.png')
plt.show()

# %%
clf = RandomForestClassifier(n_estimators=300, 
                             criterion='gini', 
                             max_depth=16, 
                             #min_samples_split=2, 
                             #min_samples_leaf=1, 
                             max_features=0.3, 
                             #bootstrap=True,
                             oob_score=True,
                             random_state=23)

# %%
start_time = datetime.now()
print(datetime.ctime(start_time))

clf.fit(enc_train_x_asam, train_y)

pred_y_ae_RF = cross_val_predict(estimator=clf,
                              X=np.array(enc_test_x_asam),
                              y=test_y,
                              cv=KFold(n_splits=5, random_state=23),
                              n_jobs=2)

time_elapsed = datetime.now() - start_time 
print("Time elapsed (hh:mm:ss.ms) {}".format(time_elapsed))

print(sm.classification_report(test_y, pred_y_ae_RF,digits=4))
# Out:
# Mon Jul 15 13:55:13 2019
# Time elapsed (hh:mm:ss.ms) 1:19:45.315190
#               precision    recall  f1-score   support
#
#            0     0.9903    0.9869    0.9886    134675
#            1     0.9868    0.9903    0.9886    133812
#
#    micro avg     0.9886    0.9886    0.9886    268487
#    macro avg     0.9886    0.9886    0.9886    268487
# weighted avg     0.9886    0.9886    0.9886    268487

# %%
plot_roc_cm(pred_y_ae_RF, pred_y_ae_RF, './Figures/ROC_ae_rf_E100MaxfautoMaxdnoneBootT_redds'+str(dsnum)+'bal.png', './Figures/CM_ae_rf_E100MaxfautoMaxdnoneBootT_redds'+str(dsnum)+'bal.png')

# %% [markdown]
# ### **---------- RF with spae encoded DS ----------**

# %%
start_time = datetime.now()
print(datetime.ctime(start_time))

clf.fit(enc_train_x_spsam, train_y)

pred_y_spae_RF = cross_val_predict(estimator=clf,
                              X=np.array(enc_test_x_spsam),
                              y=test_y,
                              cv=KFold(n_splits=5, random_state=23),
                              n_jobs=2)

time_elapsed = datetime.now() - start_time 
print("Time elapsed (hh:mm:ss.ms) {}".format(time_elapsed))

print(sm.classification_report(test_y, pred_y_spae_RF,digits=4))
# Out:
# Mon Jul 15 15:14:59 2019
# Time elapsed (hh:mm:ss.ms) 1:16:25.961135
#               precision    recall  f1-score   support
#
#            0     0.9939    0.9885    0.9912    134675
#            1     0.9885    0.9939    0.9912    133812
#
#    micro avg     0.9912    0.9912    0.9912    268487
#    macro avg     0.9912    0.9912    0.9912    268487
# weighted avg     0.9912    0.9912    0.9912    268487

# %%
plot_roc_cm(pred_y_spae_RF, pred_y_spae_RF, './Figures/ROC_spae_rf_E100MaxfautoMaxdnoneBootT_redds'+str(dsnum)+'bal.png', './Figures/CM_spae_rf_E100MaxfautoMaxdnoneBootT_redds'+str(dsnum)+'bal.png')

# %% [markdown]
# ### **---------- RF with pca DS ----------**

# %%
start_time = datetime.now()
print(datetime.ctime(start_time))

clf.fit(train_x_pca, train_y)

pred_y_pca_RF = cross_val_predict(estimator=clf,
                              X=np.array(test_x_pca),
                              y=test_y,
                              cv=KFold(n_splits=5, random_state=23),
                              n_jobs=2)

time_elapsed = datetime.now() - start_time 
print("Time elapsed (hh:mm:ss.ms) {}".format(time_elapsed))

print(sm.classification_report(test_y, pred_y_pca_RF,digits=4))
# Out:
# Mon Jul 15 16:31:25 2019
# Time elapsed (hh:mm:ss.ms) 0:43:42.584631
#               precision    recall  f1-score   support
#
#            0     0.9867    0.9905    0.9886    134675
#            1     0.9904    0.9866    0.9885    133812
#
#    micro avg     0.9886    0.9886    0.9886    268487
#    macro avg     0.9886    0.9886    0.9886    268487
# weighted avg     0.9886    0.9886    0.9886    268487

# %%
plot_roc_cm(pred_y_pca_RF, pred_y_pca_RF, './Figures/ROC_pca_rf_E100MaxfautoMaxdnoneBootT_redds'+str(dsnum)+'bal.png', './Figures/CM_pca_rf_E100MaxfautoMaxdnoneBootT_redds'+str(dsnum)+'bal.png')

# %%
print(pred_y_ae_RF.shape)
print(pred_y_spae_RF.shape)
print(pred_y_pca_RF.shape)
# Out:
# (268487,)
# (268487,)
# (268487,)

# %%
false_positive_rate_ae_RF, recall_ae_RF, thresholds_ae_RF = roc_curve(test_y, pred_y_ae_RF)
roc_auc_ae_RF = auc(false_positive_rate_ae_RF, recall_ae_RF)
false_positive_rate_spae_RF, recall_spae_RF, thresholds_spae_RF = roc_curve(test_y, pred_y_spae_RF)
roc_auc_spae_RF = auc(false_positive_rate_spae_RF, recall_spae_RF)
false_positive_rate_pca_RF, recall_pca_RF, thresholds_pca_RF = roc_curve(test_y, pred_y_pca_RF)
roc_auc_pca_RF = auc(false_positive_rate_pca_RF, recall_pca_RF)

plt.figure(figsize=(15,7))
plt.title('Receiver Operating Characteristic (ROC)', fontsize=16)

plt.plot(false_positive_rate_ae_RF, recall_ae_RF, 'c', label = 'AUC AE + RF = %0.3f' %roc_auc_ae_RF)
plt.plot(false_positive_rate_spae_RF, recall_spae_RF, 'm', label = 'AUC SAE + RF = %0.3f' %roc_auc_spae_RF)
plt.plot(false_positive_rate_pca_RF, recall_pca_RF, 'black', label = 'AUC PCA + RF = %0.3f' %roc_auc_pca_RF)

plt.legend(loc='lower right', fontsize=14)
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
# plt.ylim([0.97,1.0])

plt.ylabel('Recall - TPR', fontsize=14)
plt.xlabel('Fall-out (1-Specificity) - FPR', fontsize=14)
plt.savefig('./Figures/ROC_allRFmodels'+str(dsnum)+'bal.png')
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.title('Receiver Operating Characteristic (ROC) Zoom in', fontsize=16)

plt.plot(false_positive_rate_ae_RF, recall_ae_RF, 'c', label = 'AUC AE + RF = %0.3f' %roc_auc_ae_RF)
plt.plot(false_positive_rate_spae_RF, recall_spae_RF, 'm', label = 'AUC SAE + RF = %0.3f' %roc_auc_spae_RF)
plt.plot(false_positive_rate_pca_RF, recall_pca_RF, 'black', label = 'AUC PCA + RF = %0.3f' %roc_auc_pca_RF)

plt.legend(loc='lower right', fontsize=14)
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0.0,1.0])
# plt.ylim([0.0,1.0])
plt.ylim([0.955,1.0])

plt.ylabel('Recall - TPR', fontsize=14)
plt.xlabel('Fall-out (1-Specificity) - FPR', fontsize=14)
plt.savefig('./Figures/ROC_allRFmodels'+str(dsnum)+'bal_zoom.png')
plt.show()

# %%
classi_ae_RF = "AE+RF"
acc_ae_RF = (sm.accuracy_score(test_y, pred_y_ae_RF)*100) 
pre_ae_RF = (sm.precision_score(test_y, pred_y_ae_RF)*100) 
recall_ae_RF = (sm.recall_score(test_y, pred_y_ae_RF)*100) 
f1score_ae_RF = (sm.f1_score(test_y, pred_y_ae_RF)*100)

classi_spae_RF = "SAE+RF"
acc_spae_RF = (sm.accuracy_score(test_y, pred_y_spae_RF)*100) 
pre_spae_RF = (sm.precision_score(test_y, pred_y_spae_RF)*100) 
recall_spae_RF = (sm.recall_score(test_y, pred_y_spae_RF)*100) 
f1score_spae_RF = (sm.f1_score(test_y, pred_y_spae_RF)*100)

classi_pca_RF = "PCA+RF"
acc_pca_RF = (sm.accuracy_score(test_y, pred_y_pca_RF)*100) 
pre_pca_RF = (sm.precision_score(test_y, pred_y_pca_RF)*100) 
recall_pca_RF = (sm.recall_score(test_y, pred_y_pca_RF)*100) 
f1score_pca_RF = (sm.f1_score(test_y, pred_y_pca_RF)*100)


print('Classifier\tAcc\tPreci\tRecall\tF1Score')
print('{0:}\t\t{1:.2f}\t{2:.2f}\t{3:.2f}\t{4:.2f}'.format(classi_ae_RF, acc_ae_RF, pre_ae_RF, recall_ae_RF, f1score_ae_RF))
print('{0:}\t\t{1:.2f}\t{2:.2f}\t{3:.2f}\t{4:.2f}'.format(classi_spae_RF, acc_spae_RF, pre_spae_RF, recall_spae_RF, f1score_spae_RF))
print('{0:}\t\t{1:.2f}\t{2:.2f}\t{3:.2f}\t{4:.2f}'.format(classi_pca_RF, acc_pca_RF, pre_pca_RF, recall_pca_RF, f1score_pca_RF))
# Out:
# Classifier	Acc	Preci	Recall	F1Score
# AE+RF		98.86	98.68	99.03	98.86
# SAE+RF		99.12	98.85	99.39	99.12
# PCA+RF		98.86	99.04	98.66	98.85

# %%
f1list = [["AE+RF",f1score_ae_RF],["SAE+RF",f1score_spae_RF],["PCA+RF",f1score_pca_RF]]

xs, ys = [*zip(*f1list)]

# '{:.2f}'.format(f1score_ae_ann)

plt.figure(figsize=(8,6), )
plt.barh(xs, ys, color = "purple")
plt.title("F1 score vs Classifier", fontsize=16)
plt.xlabel("Classifier", fontsize=14)
plt.ylabel("F1 score", fontsize=14)
plt.xticks(np.arange(0, 101, 10), fontsize=12)
plt.yticks(fontsize=12, fontweight='bold')

for i, v in enumerate(ys):
    plt.text(v+1, i+0.1, '{:.2f}'.format(v), color='purple', fontsize=14)

plt.savefig('./Figures/F1scoreplot_allRFmodels'+str(dsnum)+'bal.png')
plt.show()
